# %%
import pandas as pd

# %%
gain_1 = {'renewable energy': 'Supporting renewable energy will lower carbon emissions while providing a sustainable and resilient power source for the future.',
 'public transportation': 'Expanding public transportation will reduce traffic congestion and provide affordable commuting options for all urban residents.',
 'mental health services': 'By increasing funding for mental health services, the government can improve overall community well-being and reduce long-term social costs.',
 'urban green spaces': 'Supporting urban green spaces will improve city air quality and offer essential recreational areas for crowded metropolitan populations.',
 'wildlife conservation': 'Investing in wildlife conservation helps preserve vital biodiversity and maintains the balance of delicate natural ecosystems.',
 'high-speed rail': 'By building high-speed rail, we can offer travelers a fast and environmentally friendly alternative to domestic air travel.',
 'universal childcare': 'Investing in universal childcare will allow more parents to work while ensuring children receive high-quality early education.',
 'affordable housing': 'Supporting affordable housing will reduce homelessness and provide economic stability for low-income families across the nation.',
 'rural broadband access': 'By increasing funding for rural broadband access, the government bridges the digital divide and stimulates remote economic growth.',
 'clean water infrastructure': 'Investing in clean water infrastructure ensures that every citizen has reliable access to safe and filtered drinking water.',
 'teacher training programs': 'Supporting teacher training programs will improve student learning outcomes and strengthen the overall quality of the national workforce.',
 'vocational education': 'By prioritizing vocational education, the government equips students with specialized skills that meet the immediate needs of industry.',
 'carbon capture technology': 'Investing in carbon capture technology will help mitigate climate change by removing harmful greenhouse gases from the atmosphere.',
 'cybersecurity defense': 'Supporting cybersecurity defense will protect sensitive national data and secure critical infrastructure from malicious digital attacks.',
 'early childhood development': 'By increasing funding for early childhood development, we ensure better educational attainment and higher lifetime success for children.',
 'sustainable agriculture': 'Investing in sustainable agriculture will preserve soil health and guarantee a reliable food supply for future generations.',
 'public health research': 'Supporting public health research will lead to innovative medical breakthroughs that extend life expectancy and improve wellness.',
 'disaster resilient infrastructure': 'By constructing disaster resilient infrastructure, the government can save lives and reduce the costs of emergency recovery efforts.',
 'smart city technology': 'Investing in smart city technology will optimize urban resource management and improve the daily lives of city dwellers.',
 'space exploration': 'Supporting space exploration will drive technological innovation and expand our scientific understanding of the vast universe.',
 'quantum computing research': 'By increasing funding for quantum computing research, the country can achieve massive breakthroughs in processing power and encryption.',
 'elderly care facilities': 'Investing in elderly care facilities will ensure that our aging population receives the dignity and medical support they deserve.',
 'ocean plastic removal': 'Supporting ocean plastic removal will protect marine life and restore the health of our vital aquatic ecosystems.',
 'forest restoration': 'By prioritizing forest restoration, the government can sequester carbon and provide critical habitats for many endangered species.',
 'youth mentorship programs': 'Investing in youth mentorship programs will guide young people toward successful careers and reduce local crime rates.',
 'domestic manufacturing': 'Supporting domestic manufacturing will create high-quality jobs and reduce our national reliance on complex foreign supply chains.',
 'green hydrogen production': 'By increasing funding for green hydrogen production, we can decarbonize heavy industries that are difficult to electrify.',
 'literacy initiatives': 'Investing in literacy initiatives will empower citizens to participate fully in society and improve their employment prospects.',
 'veteran support services': 'Supporting veteran support services will help former service members transition smoothly into civilian life with adequate healthcare.',
 'electric vehicle charging': 'By expanding electric vehicle charging, the government encourages the adoption of clean cars and reduces fossil fuel consumption.',
 'biodiversity protection': 'Investing in biodiversity protection will safeguard the various plant and animal species that are essential for environmental health.',
 'grid modernization': 'Supporting grid modernization will prevent frequent power outages and allow for the efficient integration of renewable energy sources.',
 'small business grants': 'By providing small business grants, the government fosters local innovation and supports the backbone of the national economy.',
 'maternal health care': 'Investing in maternal health care will reduce pregnancy complications and ensure healthier outcomes for both mothers and babies.',
 'workforce retraining': 'Supporting workforce retraining will help employees adapt to new technologies and remain competitive in a changing labor market.',
 'emergency response systems': 'By upgrading emergency response systems, the government can shorten arrival times and save more lives during critical incidents.',
 'public library systems': 'Investing in public library systems will provide free access to educational resources and information for all community members.',
 'pedestrian safety infrastructure': 'Supporting pedestrian safety infrastructure will reduce traffic accidents and make our neighborhoods more walkable and safer for everyone.',
 'organic farming subsidies': 'By increasing funding for organic farming subsidies, we can encourage healthier food production and reduce harmful pesticide use.',
 'semiconductor production': 'Investing in semiconductor production will secure the domestic supply of essential chips for all modern electronic devices.',
 'artificial intelligence ethics': 'Supporting artificial intelligence ethics will ensure that new technologies are developed responsibly and for the benefit of humanity.',
 'bilingual education': 'By prioritizing bilingual education, the government prepares students for a globalized world while enhancing their cognitive development.',
 'waste-to-energy plants': 'Investing in waste-to-energy plants will reduce landfill use and generate clean power from discarded community materials.',
 'social housing projects': 'Supporting social housing projects will provide vulnerable populations with the security and dignity of a permanent home.',
 'preventative medicine': 'By increasing funding for preventative medicine, we can reduce the prevalence of chronic diseases and lower healthcare costs.',
 'flood defense systems': 'Investing in flood defense systems will protect homes and businesses from the increasing threat of extreme weather events.',
 'community college funding': 'Supporting community college funding will make higher education more accessible and provide affordable pathways to technical careers.',
 'renewable heating systems': 'By subsidizing renewable heating systems, the government helps households reduce their energy bills and their total carbon footprint.',
 'precision medicine': 'Investing in precision medicine will allow for customized treatments that significantly improve patient recovery rates and health outcomes.',
 'coastal erosion prevention': 'Supporting coastal erosion prevention will safeguard seaside communities and protect valuable shoreline property from rising sea levels.',
 'adult education centers': 'By funding adult education centers, the government helps citizens learn new skills throughout their lives to stay employed.',
 'rare disease research': 'Investing in rare disease research will provide hope and life-saving treatments for patients with currently neglected conditions.',
 'national park maintenance': 'By increasing funding for national park maintenance, we ensure that future generations can enjoy the beauty of our wilderness.',
 'solar panel manufacturing': 'Investing in solar panel manufacturing will create local jobs and accelerate the national transition toward a clean energy economy.',
 'clean air initiatives': 'Supporting clean air initiatives will reduce respiratory illnesses and improve the general health of citizens in urban areas.',
 'prison rehabilitation programs': 'By funding prison rehabilitation programs, the government can reduce recidivism and help former inmates reintegrate into productive society.',
 'drought resistant crops': 'Investing in drought resistant crops will ensure food security in regions that are increasingly affected by changing climate patterns.',
 'high-tech startups': 'Supporting high-tech startups will drive economic growth and foster the creation of groundbreaking solutions for modern problems.',
 'marine protected areas': 'By expanding marine protected areas, the government can restore fish populations and protect sensitive underwater habitats from damage.',
 'after-school programs': 'Investing in after-school programs will keep students engaged in safe activities and provide extra support for their education.',
 'geothermal energy': 'Supporting geothermal energy will provide a constant and reliable source of clean power from the heat of the earth.',
 'biofuel development': 'By increasing funding for biofuel development, we can create a sustainable alternative to fossil fuels for the aviation industry.',
 'language preservation': 'Investing in language preservation will protect cultural diversity and honor the unique heritage of indigenous communities.',
 'public arts programs': 'Supporting public arts programs will enrich the cultural life of communities and encourage creative expression among all citizens.',
 'infectious disease surveillance': 'By improving infectious disease surveillance, the government can detect outbreaks early and prevent the spread of global pandemics.',
 'cycling infrastructure': 'Investing in cycling infrastructure will encourage healthy transportation and reduce the number of cars on the city streets.',
 'desalination plants': 'Supporting desalination plants will provide a critical supply of fresh water for regions facing severe and persistent droughts.',
 'solid waste management': 'By modernizing solid waste management, the government can increase recycling rates and reduce the environmental impact of trash.',
 'regenerative medicine': 'Investing in regenerative medicine will lead to new therapies that can repair damaged tissues and cure chronic injuries.',
 'local food systems': 'Supporting local food systems will reduce transport emissions and ensure that fresh produce is available to every neighborhood.',
 'bridge repair projects': 'By prioritizing bridge repair projects, the government ensures the safety and efficiency of the national transportation network.',
 'special education resources': 'Investing in special education resources will help students with disabilities reach their full potential and succeed in school.',
 'battery storage technology': 'Supporting battery storage technology will allow us to store renewable energy for use when the sun is not shining.',
 'indigenous land management': 'By empowering indigenous land management, the government can utilize traditional knowledge to protect the environment and promote sustainability.',
 'remote learning tools': 'Investing in remote learning tools will expand educational access for students living in isolated or underserved geographic areas.',
 'satellite communication': 'Supporting satellite communication will improve global connectivity and enhance our ability to monitor the planet from above.',
 'water recycling systems': 'By increasing funding for water recycling systems, we can conserve natural water sources and reduce the risk of shortages.',
 'labor market transparency': 'Investing in labor market transparency will help workers find better opportunities and ensure that wages are fair and competitive.',
 'microgrid development': 'Supporting microgrid development will increase local energy security and provide backup power for communities during major outages.',
 'sustainable forestry': 'By practicing sustainable forestry, the government can protect timber resources while maintaining the health of the broader environment.',
 'physical education': 'Investing in physical education will improve student health and encourage lifelong habits of fitness and general wellness.',
 'immunization programs': 'Supporting immunization programs will protect the public from dangerous diseases and ensure the overall health of the nation.',
 'circular economy initiatives': 'By funding circular economy initiatives, we can reduce waste and create a more efficient system for using natural resources.',
 'homelessness prevention': 'Investing in homelessness prevention will help individuals keep their homes and reduce the need for expensive emergency services.',
 'tidal power': 'Supporting tidal power will harness the predictable energy of the ocean to provide a clean and renewable electricity source.',
 'urban farming': 'By encouraging urban farming, the government can provide fresh nutrition locally while cooling down hot city environments.',
 'citizen science projects': 'Investing in citizen science projects will engage the public in research and gather valuable data for environmental protection.',
 'dam safety': 'Supporting dam safety will prevent catastrophic flooding and protect the communities that live downstream from large water reservoirs.',
 'public square renovation': 'By funding public square renovation, the government creates vibrant meeting places that support local businesses and social cohesion.',
 'space debris removal': 'Investing in space debris removal will protect essential satellites and ensure that low Earth orbit remains safe for travel.',
 'advanced robotics': 'Supporting advanced robotics will increase industrial productivity and help humans perform tasks that are dangerous or repetitive.',
 'community health clinics': 'By increasing funding for community health clinics, we provide essential medical services to those who need them most.',
 'historic preservation': 'Investing in historic preservation will save our cultural landmarks and promote local tourism by showcasing our national heritage.',
 'food security programs': 'Supporting food security programs will ensure that no citizen goes hungry and that everyone has access to nutritious meals.',
 'public broadcasting': 'By funding public broadcasting, the government ensures that all citizens have access to reliable news and high-quality educational content.',
 'peatland restoration': 'Investing in peatland restoration will help sequester vast amounts of carbon and provide a unique habitat for many species.',
 'stem cell research': 'Supporting stem cell research will lead to groundbreaking medical treatments that can regenerate organs and cure complex diseases.',
 'district heating': 'By implementing district heating, the government can provide an efficient way to keep homes warm using sustainable energy sources.',
 'migrant integration services': 'Investing in migrant integration services will help new arrivals contribute to the economy and build a more cohesive society.',
 'energy efficient appliances': 'Supporting energy efficient appliances will lower household electricity bills and reduce the total demand on the national power grid.',
 'rural healthcare clinics': 'By funding rural healthcare clinics, the government ensures that citizens in remote areas have access to life-saving medical care.',
 'national security technology': 'Investing in national security technology will protect the country from modern threats and safeguard our sovereign borders.',
 'neighborhood revitalization': 'Supporting neighborhood revitalization will improve living conditions and stimulate local economic activity in previously neglected areas.',
 'online safety education': 'By increasing funding for online safety education, we can protect citizens from digital fraud and harmful internet behavior.',
 'sustainable fashion research': 'Investing in sustainable fashion research will help reduce the environmental impact of the clothing industry and promote recycling.',
 'park and ride': 'Supporting park and ride facilities will reduce city traffic congestion by encouraging commuters to use public transit systems.',
 'industrial decarbonization': 'By prioritizing industrial decarbonization, the government can help heavy manufacturers transition to cleaner and more sustainable production methods.',
 'pediatric care': 'Investing in pediatric care will ensure that children receive the specialized medical attention they need to grow up healthy.',
 'river cleanup operations': 'Supporting river cleanup operations will restore water quality and protect the diverse wildlife that depends on our waterways.',
 'weather forecasting systems': 'By upgrading weather forecasting systems, the government can provide more accurate warnings that save lives during severe storms.',
 'green building materials': 'Investing in green building materials will reduce the environmental footprint of the construction industry and improve home efficiency.',
 'soil health restoration': 'Supporting soil health restoration will increase agricultural productivity and allow the ground to absorb more atmospheric carbon.',
 'public transit subsidies': 'By providing public transit subsidies, the government makes commuting more affordable and encourages the use of eco-friendly transportation.',
 'aerospace engineering': 'Investing in aerospace engineering will drive the development of more efficient aircraft and support national leadership in flight technology.',
 'mental health apps': 'Supporting mental health apps will provide accessible and immediate support for individuals who cannot visit a traditional clinic.',
 'clean energy jobs': 'By funding clean energy jobs, the government creates a future-proof workforce that supports the transition to a green economy.',
 'oceanographic research': 'Investing in oceanographic research will deepen our understanding of the sea and help us protect marine resources effectively.',
 'community gardens': 'Supporting community gardens will foster social connections and provide residents with a local source of fresh and healthy produce.',
 'disability access improvements': 'By prioritizing disability access improvements, the government ensures that all public spaces are inclusive and usable for every citizen.',
 'hydrogen fuel cells': 'Investing in hydrogen fuel cells will provide a clean energy solution for long-haul trucks and other heavy transport vehicles.',
 'carbon sequestration': 'Supporting carbon sequestration will allow the nation to actively remove greenhouse gases from the air to fight warming.',
 'anti-smoking campaigns': 'By increasing funding for anti-smoking campaigns, we can reduce the rates of lung disease and lower public healthcare costs.',
 'autonomous vehicle safety': 'Investing in autonomous vehicle safety will ensure that self-driving cars are developed in a way that protects every road user.',
 'microchip design': 'Supporting microchip design will foster local innovation and ensure that we remain competitive in the global electronics market.',
 'youth sports facilities': 'By building youth sports facilities, the government encourages healthy lifestyles and provides positive recreational outlets for young people.',
 'sustainable tourism': 'Investing in sustainable tourism will protect our natural landmarks while bringing economic benefits to the communities that host visitors.',
 'wastewater treatment': 'Supporting wastewater treatment will prevent environmental pollution and allow for the safe reuse of water in agricultural projects.',
 'nutrition assistance': 'By providing nutrition assistance, the government ensures that low-income families have the resources to purchase healthy and balanced meals.',
 'reforestation projects': 'Investing in reforestation projects will help restore natural forests that clean our air and provide a home for wildlife.',
 'advanced materials science': 'Supporting advanced materials science will lead to the creation of stronger and lighter products for construction and medical use.',
 'family planning services': 'By funding family planning services, the government empowers individuals to make informed decisions about their reproductive health and future.',
 'cyber-physical systems': 'Investing in cyber-physical systems will improve the efficiency and safety of modern industrial plants and municipal utilities.',
 'public records digitization': 'Supporting public records digitization will make government information more transparent and easier for citizens to access online.',
 'clean cooking fuels': 'By promoting clean cooking fuels, the government can reduce indoor air pollution and improve health outcomes for many families.',
 'wildfire prevention': 'Investing in wildfire prevention will protect homes and forests from devastating blazes while reducing harmful smoke emissions.',
 'vaccine manufacturing': 'Supporting vaccine manufacturing will ensure that the nation can respond quickly and effectively to any future health emergencies.',
 'marine biology research': 'By increasing funding for marine biology research, we can discover new medicines and better ways to protect our oceans.',
 'smart irrigation': 'Investing in smart irrigation will help farmers save water while ensuring that their crops receive the exact amount of moisture.',
 'alternative protein research': 'Supporting alternative protein research will reduce the environmental impact of food production and offer more sustainable dietary choices.',
 'urban drainage systems': 'By upgrading urban drainage systems, the government can prevent city flooding and protect public infrastructure from heavy rain damage.',
 'digital literacy training': 'Investing in digital literacy training will give all citizens the skills they need to navigate the modern online world.',
 'biotechnology innovation': 'Supporting biotechnology innovation will lead to the development of new crops and medicines that solve global challenges.',
 'poverty alleviation': 'By prioritizing poverty alleviation, the government can create a more equitable society where everyone has a chance to succeed.',
 'public safety equipment': 'Investing in public safety equipment will provide our first responders with the tools they need to protect the community.',
 'heritage site protection': 'Supporting heritage site protection will ensure that our history is preserved for future generations to learn from and enjoy.',
 'sustainable aviation fuel': 'By increasing funding for sustainable aviation fuel, we can reduce the carbon emissions generated by the global travel industry.',
 'green shipping lanes': 'Investing in green shipping lanes will encourage the use of eco-friendly vessels and protect the health of our oceans.',
 'low-carbon cement': 'Supporting low-carbon cement will significantly reduce the environmental impact of building our cities and national infrastructure projects.',
 'integrated pest management': 'By promoting integrated pest management, the government helps farmers control pests naturally while reducing the use of toxic chemicals.',
 'nuclear power plants': 'Investing in nuclear power plants will provide a massive amount of carbon-free baseload electricity to support a modern economy.',
 'universal basic income': 'By implementing universal basic income, the government can provide a financial safety net that reduces poverty and stimulates local spending.',
 'high-density housing': 'Supporting high-density housing will make urban living more affordable while reducing the environmental impact of suburban sprawl.',
 'semiconductor research labs': 'Investing in semiconductor research labs will drive the next generation of computing power and secure national technological leadership.',
 'pediatric mental health': 'By increasing funding for pediatric mental health, we can ensure that children receive the emotional support necessary for healthy development.',
 'coastal levee systems': 'Investing in coastal levee systems will protect vulnerable low-lying communities from the increasing threat of storm surges and floods.',
 'carbon tax infrastructure': 'Supporting carbon tax infrastructure will create a market-based incentive for companies to reduce their greenhouse gas emissions effectively.',
 'public Wi-Fi networks': 'By expanding public Wi-Fi networks, the government provides essential internet access to citizens who cannot afford private data plans.',
 'rare earth mining': 'Investing in rare earth mining will secure the domestic supply of minerals needed for high-tech electronics and green technologies.',
 'sustainable textile production': 'Supporting sustainable textile production will reduce the massive water usage and chemical waste generated by the traditional fashion industry.',
 'recycled plastic roads': 'By building recycled plastic roads, the government can repurpose waste materials into durable and long-lasting transportation infrastructure.',
 'hydrogen fueling stations': 'Investing in hydrogen fueling stations will enable the widespread use of zero-emission fuel cell vehicles for long-distance travel.',
 'organic waste collection': 'Supporting organic waste collection will divert compostable materials from landfills and create high-quality fertilizer for local agriculture.',
 'marine turbine arrays': 'By deploying marine turbine arrays, the government can harness the immense power of ocean currents to generate renewable electricity.',
 'smart electrical meters': 'Investing in smart electrical meters will empower consumers to monitor their energy use and reduce their monthly utility costs.',
 'public drone delivery': 'Supporting public drone delivery will revolutionize the transport of emergency medical supplies to remote or hard-to-reach locations.',
 'quantum encryption tools': 'By developing quantum encryption tools, the government can protect sensitive national communications from being intercepted by future quantum computers.',
 'vertical farming facilities': 'Investing in vertical farming facilities will allow cities to grow fresh produce year-round using minimal land and water resources.',
 'urban canopy expansion': 'Supporting urban canopy expansion will provide natural shade that lowers city temperatures and improves the local air quality.',
 'disaster warning apps': 'By funding disaster warning apps, the government can provide citizens with real-time alerts that save lives during extreme weather events.',
 'high-tech vocational labs': 'Supporting high-tech vocational labs will give students hands-on experience with the advanced machinery used in modern industrial sectors.',
 'bilingual signage systems': 'By implementing bilingual signage systems, the government makes public navigation easier and more inclusive for diverse linguistic communities.',
 'public water filtration': 'Investing in public water filtration will ensure that all residents have access to high-quality drinking water straight from the tap.',
 'migrant job training': 'Supporting migrant job training will help new residents find stable employment and contribute their skills to the national economy.',
 'veteran housing vouchers': 'By increasing funding for veteran housing vouchers, the government can eliminate homelessness among those who have served in the military.',
 'clean energy startups': 'Investing in clean energy startups will accelerate the development of innovative technologies that help the world transition away from carbon.',
 'electric bus fleets': 'Supporting electric bus fleets will eliminate tailpipe emissions in city centers and provide a quieter, cleaner commute for passengers.',
 'renewable cooling systems': 'By prioritizing renewable cooling systems, the government can reduce the energy demand and carbon footprint of air conditioning in buildings.',
 'sustainable fishing gear': 'Investing in sustainable fishing gear will reduce bycatch and help protect the long-term health of our global fish populations.',
 'ocean thermal energy': 'Supporting ocean thermal energy will provide a constant source of clean power by utilizing the temperature difference in sea water.',
 'forest fire lookouts': 'By funding forest fire lookouts, the government can detect blazes early and prevent them from turning into uncontrollable disasters.',
 'public data centers': 'Investing in public data centers will ensure that citizens have a secure and sovereign place to store essential government information.',
 'open science initiatives': 'Supporting open science initiatives will make research findings accessible to everyone, speeding up the pace of global scientific discovery.',
 'community tool libraries': 'By creating community tool libraries, the government allows neighbors to share expensive equipment, reducing waste and fostering local cooperation.',
 'neighborhood tool sharing': 'Investing in neighborhood tool sharing will promote a circular economy while helping residents maintain their homes at a lower cost.',
 'specialized nursing education': 'Supporting specialized nursing education will address the healthcare worker shortage and improve the quality of care in hospitals.',
 'rare mineral stockpiles': 'By maintaining rare mineral stockpiles, the government can protect domestic industries from sudden international supply chain disruptions.',
 'advanced polymer research': 'Investing in advanced polymer research will lead to the creation of new materials that are more durable and easily recyclable.',
 'public compost facilities': 'Supporting public compost facilities will help turn residential food scraps into valuable nutrients for local parks and farms.',
 'sustainable concrete development': 'By funding sustainable concrete development, the government can reduce the massive carbon footprint associated with traditional urban construction projects.',
 'tidal surge barriers': 'Investing in tidal surge barriers will protect major coastal cities from the devastating impacts of rising sea levels and storms.',
 'autonomous shuttle loops': 'Supporting autonomous shuttle loops will provide a modern and efficient transportation solution for airports, campuses, and city centers.',
 'youth coding camps': 'By increasing funding for youth coding camps, the government prepares the next generation for high-paying jobs in the technology sector.',
 'urban waterway restoration': 'Investing in urban waterway restoration will turn neglected city canals into beautiful public spaces that support local wildlife.',
 'public charging docks': 'Supporting public charging docks for mobile devices will provide a helpful and modern service for citizens in busy areas.',
 'smart traffic signals': 'By implementing smart traffic signals, the government can optimize the flow of cars to reduce idling and greenhouse emissions.',
 'industrial heat pumps': 'Investing in industrial heat pumps will allow factories to replace fossil fuel boilers with high-efficiency electrical heating solutions.',
 'methane leak detection': 'Supporting methane leak detection will help energy companies find and fix emissions, significantly slowing the rate of global warming.',
 'aquifer recharge systems': 'By building aquifer recharge systems, the government can replenish underground water supplies and ensure long-term drought resilience for communities.',
 'sustainable irrigation tech': 'Investing in sustainable irrigation tech will help farmers grow more food using significantly less water and fewer chemical inputs.',
 'citizen science apps': 'Supporting citizen science apps will empower the public to help researchers monitor biodiversity and track environmental changes in real-time.',
 'public health laboratories': 'By modernizing public health laboratories, the government can speed up the testing and diagnosis of dangerous new infectious diseases.',
 'emergency surgical centers': 'Investing in emergency surgical centers will ensure that trauma patients receive life-saving operations as quickly as possible during a crisis.',
 'rehabilitative sports programs': 'Supporting rehabilitative sports programs will help individuals with injuries or disabilities improve their physical health and social well-being.',
 'accessible playground equipment': 'By installing accessible playground equipment, the government ensures that all children, regardless of physical ability, can enjoy outdoor play.',
 'sustainable livestock feed': 'Investing in sustainable livestock feed will reduce the environmental impact of meat production and lower the cost for farmers.',
 'precision forestry tools': 'Supporting precision forestry tools will allow for more accurate tree planting and management to maximize carbon sequestration efforts.',
 'biodiversity corridors': 'By creating biodiversity corridors, the government can link fragmented habitats and allow wildlife to move safely across large distances.',
 'urban wetland preservation': 'Investing in urban wetland preservation will provide natural flood protection while filtering pollutants from city runoff before it reaches the sea.',
 'public transit sensors': 'Supporting public transit sensors will provide real-time data that helps commuters plan their trips more efficiently and avoids overcrowding.',
 'renewable aviation research': 'By funding renewable aviation research, the government can help the airline industry transition to zero-emission flight technologies for travel.',
 'clean steel manufacturing': 'Investing in clean steel manufacturing will utilize green hydrogen to produce essential building materials without releasing any carbon dioxide.',
 'green ammonia production': 'Supporting green ammonia production will provide a carbon-free alternative for maritime fuel and agricultural fertilizers used across the globe.',
 'sustainable brick making': 'By increasing funding for sustainable brick making, the government can encourage the use of eco-friendly building blocks in construction.',
 'bio-based plastics': 'Investing in bio-based plastics will provide a renewable alternative to petroleum-based materials that never decompose in the natural environment.',
 'mycelium building materials': 'Supporting mycelium building materials will promote the use of fungi-based products that are biodegradable and have high insulation properties.',
 'recycled aluminum plants': 'By building recycled aluminum plants, the government can save immense amounts of energy compared to producing metal from raw ore.',
 'public art galleries': 'Investing in public art galleries will make culture accessible to everyone and stimulate the local economy through increased cultural tourism.',
 'community radio stations': 'Supporting community radio stations will provide a platform for local voices and ensure that important information reaches all residents.',
 'youth orchestra programs': 'By funding youth orchestra programs, the government can foster a love for the arts and build teamwork among young musicians.',
 'senior digital literacy': 'Investing in senior digital literacy will help older citizens stay connected with their families and safely navigate modern online services.',
 'migrant language classes': 'Supporting migrant language classes will help new arrivals integrate into the community and find better employment opportunities more quickly.',
 'refugee resettlement centers': 'By increasing funding for refugee resettlement centers, the government provides a safe and supportive start for families fleeing from conflict.',
 'public swimming pools': 'Investing in public swimming pools will promote physical fitness and provide a safe place for children to learn how to swim.',
 'municipal fiber optics': 'Supporting municipal fiber optics will bring ultra-high-speed internet to every home, ensuring that no neighborhood is left behind digitally.',
 'clean construction equipment': 'By subsidizing clean construction equipment, the government can reduce the noise and air pollution generated by urban development projects.',
 'electric freight rail': 'Investing in electric freight rail will move heavy goods across the country more efficiently and with significantly lower carbon emissions.',
 'autonomous delivery bots': 'Supporting autonomous delivery bots will reduce the number of delivery vans on the road, lessening urban traffic and pollution.',
 'sustainable packaging research': 'By funding sustainable packaging research, the government can help companies eliminate single-use plastics and reduce the amount of waste.',
 'ocean acidification monitoring': 'Investing in ocean acidification monitoring will help scientists understand the changing chemistry of our seas and protect sensitive marine life.',
 'coral reef restoration': 'Supporting coral reef restoration will help bring back the underwater nurseries that support a quarter of all marine species.',
 'mangrove forest protection': 'By prioritizing mangrove forest protection, the government can create a natural barrier against storm surges and store vast carbon amounts.',
 'peatland rewetting projects': 'Investing in peatland rewetting projects will stop the release of carbon from dried-out bogs and restore vital wetland ecosystems.',
 'glacier preservation tech': 'Supporting glacier preservation tech will help slow the melting of critical freshwater sources for millions of people around the world.',
 'river flow sensors': 'By installing river flow sensors, the government can provide early warnings for floods and better manage water resources for agriculture.',
 'public park toilets': 'Investing in public park toilets will improve the hygiene and accessibility of our outdoor spaces for all community members.',
 'sidewalk repair programs': 'Supporting sidewalk repair programs will make cities safer for pedestrians and ensure that people with disabilities can navigate easily.',
 'accessible transit vans': 'By increasing funding for accessible transit vans, the government provides essential mobility for citizens who cannot use standard bus systems.',
 'electric ferry services': 'Investing in electric ferry services will provide a quiet and zero-emission way for commuters to travel across local water bodies.',
 'sustainable port infrastructure': 'Supporting sustainable port infrastructure will help the shipping industry reduce its environmental impact while maintaining vital global trade links.',
 'green hydrogen storage': 'By funding green hydrogen storage, the government can ensure that renewable energy is available even during times of low production.',
 'solid state batteries': 'Investing in solid state batteries will lead to electric vehicles that charge faster and have a much longer driving range.',
 'modular reactor design': 'Supporting modular reactor design will allow for the faster and more affordable deployment of safe and clean nuclear energy.',
 'fusion energy prototypes': 'By increasing funding for fusion energy prototypes, the country moves closer to achieving a nearly limitless source of clean power.',
 'space-based solar power': 'Investing in space-based solar power will allow us to collect energy from the sun continuously without being blocked by clouds.',
 'lunar base research': 'Supporting lunar base research will pave the way for a permanent human presence on the moon and future deep-space missions.',
 'asteroid mining policy': 'By establishing asteroid mining policy, the government can encourage the responsible and peaceful exploration of minerals found in outer space.',
 'satellite internet arrays': 'Investing in satellite internet arrays will bring high-speed connectivity to the most remote and underserved parts of the entire planet.',
 'hypersonic travel research': 'Supporting hypersonic travel research will lead to a new era of ultra-fast transportation that connects global cities in record time.',
 'nanotechnology safety labs': 'By funding nanotechnology safety labs, the government ensures that new microscopic inventions are developed without harming human health or nature.',
 'synthetic biology ethics': 'Investing in synthetic biology ethics will create a framework for the responsible design of new biological organisms for medicine.',
 'genomic sequencing centers': 'Supporting genomic sequencing centers will allow doctors to identify genetic risks early and provide personalized healthcare for every patient.',
 'personalized nutrition programs': 'By funding personalized nutrition programs, the government can help citizens eat exactly what their bodies need to prevent chronic disease.',
 'preventative dental care': 'Investing in preventative dental care will reduce the incidence of painful oral diseases and lower the cost of emergency procedures.',
 'mobile health vans': 'Supporting mobile health vans will bring essential medical services directly to underserved rural communities and people experiencing homelessness.',
 'community birth centers': 'By increasing funding for community birth centers, we can provide expectant mothers with more personalized and accessible maternal care options.',
 'palliative care units': 'Investing in palliative care units will ensure that patients with terminal illnesses receive the most compassionate and dignified end-of-life support.',
 'mental health crisis': 'Supporting mental health crisis response teams will ensure that individuals in distress receive professional help rather than a police intervention.',
 'substance abuse counseling': 'By funding substance abuse counseling, the government can help individuals overcome addiction and rebuild their lives within a supportive community.',
 'homeless shelter beds': 'Supporting homeless shelter beds will ensure that every citizen has a warm and safe place to sleep during the night.',
 'domestic violence refuges': 'By increasing funding for domestic violence refuges, we provide a vital lifeline and safe haven for individuals fleeing dangerous situations.',
 'foster care support': 'Investing in foster care support will ensure that children in the system have stable homes and the resources they need.',
 'adoption assistance programs': 'Supporting adoption assistance programs will help more children find permanent and loving families through financial and legal aid for parents.',
 'early literacy kits': 'By providing early literacy kits, the government helps parents encourage reading and language development in children from a very young age.',
 'STEM kits for schools': 'Investing in STEM kits for schools will give students the tools they need to explore science and technology through hands-on learning.',
 'dual-enrollment scholarships': 'Supporting dual-enrollment scholarships will allow high school students to earn college credits early, reducing the total cost of their degree.',
 'teacher salary subsidies': "By increasing funding for teacher salary subsidies, the government can attract and retain the best educators for our nation's public schools.",
 'school meal programs': 'Investing in school meal programs ensures that every student has the nutrition they need to focus and succeed in their studies.',
 'student debt relief': 'Supporting student debt relief will allow graduates to contribute more to the economy and achieve their personal financial goals sooner.',
 'financial literacy classes': 'By funding financial literacy classes, the government empowers citizens to manage their money wisely and build long-term wealth for their families.',
 'civic education programs': 'Investing in civic education programs will help students understand how their government works and encourage them to become active voters.',
 'adult retraining grants': 'Supporting adult retraining grants will provide the financial support needed for workers to learn new skills and change their career paths.',
 'apprenticeship tax credits': 'By offering apprenticeship tax credits, the government encourages businesses to train new workers in highly skilled and well-paying technical trades.',
 'small farm equipment': 'Investing in small farm equipment will help local growers increase their productivity and compete more effectively with large industrial operations.',
 'local farmers markets': 'Supporting local farmers markets will provide communities with fresh food while keeping more money within the immediate neighborhood economy.',
 'urban beekeeping initiatives': 'By encouraging urban beekeeping initiatives, the government can help protect pollinator populations and improve the health of city-wide plant life.',
 'native wildflower meadows': 'Investing in native wildflower meadows will provide essential habitats for bees and butterflies while beautifying our public highway and parks.',
 'pollinator habitat grants': 'Supporting pollinator habitat grants will encourage private landowners to create spaces where essential insects like honeybees can thrive safely.',
 'invasive species removal': 'By funding invasive species removal, the government can protect native plants and animals from being crowded out by non-native pests.',
 'soil carbon testing': 'Investing in soil carbon testing will allow farmers to monitor how much greenhouse gas they are storing in their agricultural land.',
 'water desalinization tech': 'Supporting water desalinization tech will provide a drought-proof source of drinking water for coastal regions facing severe fresh water shortages.',
 'greywater recycling systems': 'By installing greywater recycling systems, the government can help households reuse water from sinks and showers for their garden irrigation.',
 'smart water valves': 'Investing in smart water valves will automatically detect leaks in public pipes to prevent the waste of our precious water resources.',
 'public shower facilities': 'Supporting public shower facilities will provide a vital hygiene service for people experiencing homelessness and improve overall urban public health.',
 'urban cooling centers': 'By funding urban cooling centers, the government can protect vulnerable citizens from heatstroke during increasingly frequent and intense summer heatwaves.',
 'weatherization grant programs': 'Investing in weatherization grant programs will help low-income families seal their homes to reduce energy waste and lower heating bills.',
 'energy audit services': 'Supporting energy audit services will help homeowners identify exactly where they are losing heat and how to improve their efficiency.',
 'low-interest green loans': 'By offering low-interest green loans, the government makes it easier for citizens to install solar panels or upgrade to efficient appliances.',
 'community land trusts': 'Investing in community land trusts will help preserve affordable housing by taking the cost of land out of the equation.',
 'cooperative housing models': 'Supporting cooperative housing models will allow residents to own and manage their buildings together, fostering a sense of community ownership.',
 'rent control administration': 'By funding rent control administration, the government can ensure that housing remains affordable and that tenants are protected from unfair increases.',
 'public zoning reform': 'Investing in public zoning reform will allow for more diverse and affordable housing options in neighborhoods that need them the most.',
 'neighborhood safety patrols': 'Supporting neighborhood safety patrols will provide a visible presence that helps deter crime and makes residents feel more secure in cities.',
 'de-escalation training programs': 'By increasing funding for de-escalation training programs, we can ensure that police officers handle difficult situations with minimal use of force.',
 'body-worn cameras': 'Investing in body-worn cameras will increase transparency and accountability in law enforcement while protecting both officers and the general public.',
 'forensic science labs': 'Supporting forensic science labs will speed up the processing of evidence to ensure that justice is served quickly and accurately.',
 'judicial case management': 'By modernizing judicial case management, the government can reduce court backlogs and ensure that every citizen receives a timely trial.',
 'legal aid services': 'Investing in legal aid services will provide low-income individuals with the legal representation they need to protect their fundamental rights.',
 'public defender funding': 'Supporting public defender funding will ensure that the right to a fair trial is upheld for everyone, regardless of their income.',
 'restorative justice centers': 'By creating restorative justice centers, the government can help victims and offenders find ways to heal and repair the community.',
 'victim compensation funds': 'Investing in victim compensation funds will provide financial support to those who have suffered from crimes to help them recover.',
 'anti-corruption task forces': 'Supporting anti-corruption task forces will protect public funds and ensure that government officials operate with the highest levels of integrity.',
 'election security systems': 'By upgrading election security systems, the government can protect the democratic process from foreign interference and ensure accurate vote counts.',
 'secure voting tech': 'Investing in secure voting tech will make it easier for every citizen to cast their ballot and trust the final results.',
 'government transparency portals': 'Supporting government transparency portals will allow citizens to easily see how their tax dollars are being spent by elected officials.',
 'open data APIs': 'By creating open data APIs, the government allows developers to build useful apps that help citizens interact with public services.',
 'public records archives': 'Investing in public records archives will ensure that our national history and important documents are preserved for all future generations.',
 'cultural heritage digitization': 'Supporting cultural heritage digitization will allow people to explore museum collections and historical archives from anywhere in the world.',
 'indigenous language schools': 'By funding indigenous language schools, the government can help tribal communities preserve their traditional tongues and rich cultural identity.',
 'traditional craft preservation': 'Investing in traditional craft preservation will support local artisans and ensure that ancient skills are passed down to future generations.',
 'public sculpture commissions': 'Supporting public sculpture commissions will beautify our cities and provide local artists with a platform to showcase their creative talents.',
 'community mural projects': 'By funding community mural projects, the government can turn drab urban walls into vibrant displays of local culture and storytelling.',
 'youth theater grants': 'Investing in youth theater grants will give young people a creative outlet and help them build confidence and communication skills.',
 'local film incentives': 'Supporting local film incentives will attract production companies to the area, creating jobs and boosting the local economy through tourism.',
 'sustainable tourism boards': 'By funding sustainable tourism boards, the government can promote travel that respects the environment and benefits local residents and businesses.',
 'national trail systems': 'Investing in national trail systems will provide citizens with beautiful places to hike and connect with the great outdoors.',
 'mountain bike paths': 'Supporting mountain bike paths will encourage outdoor recreation and attract adventure tourists to rural and mountainous regions.',
 'accessible hiking trails': 'Investing in accessible hiking trails will ensure that people with disabilities can enjoy the natural beauty of our national parks.',
 'urban beach maintenance': 'Supporting urban beach maintenance will keep our city shorelines clean and safe for thousands of residents to enjoy during summer.',
 'public pier repair': 'By prioritizing public pier repair, the government ensures that coastal landmarks remain safe for fishing, walking, and enjoying the ocean.',
 'riverfront boardwalks': 'Investing in riverfront boardwalks will create beautiful public pathways that stimulate local business and encourage outdoor activity along our rivers.',
 'floating solar farms': 'Supporting floating solar farms will generate clean electricity without taking up valuable land needed for farming or housing developments.',
 'wave energy converters': 'By increasing funding for wave energy converters, the government can tap into the immense and consistent power of our oceans.',
 'micro-hydro turbines': 'Investing in micro-hydro turbines will provide small-scale and environmentally friendly power for rural communities living near flowing water sources.',
 'kinetic floor tiling': 'Supporting kinetic floor tiling will allow busy public spaces like train stations to generate electricity from the footsteps of commuters.',
 'waste heat recovery': 'By implementing waste heat recovery systems, factories can capture and reuse the thermal energy that would otherwise be lost to the atmosphere.',
 'carbon-neutral glass production': 'Investing in carbon-neutral glass production will help the manufacturing sector reduce its environmental impact while producing essential building materials.',
 'sustainable rubber research': 'Supporting sustainable rubber research will help find eco-friendly alternatives to synthetic materials derived from fossil fuels for tires and industry.',
 'bio-solvent development': 'By funding bio-solvent development, the government can replace harsh industrial chemicals with safer and biodegradable alternatives made from plants.',
 'green chemistry labs': 'Investing in green chemistry labs will drive the discovery of new processes that reduce toxic waste in the manufacturing of medicines.',
 'circular textile hubs': 'Supporting circular textile hubs will allow communities to recycle old clothing into high-quality new fabrics, reducing fashion industry waste.',
 'reclaimed wood markets': 'By encouraging reclaimed wood markets, the government can reduce the demand for new timber and promote the reuse of building materials.',
 'industrial symbiosis parks': "Investing in industrial symbiosis parks will allow different factories to share resources and turn one company's waste into another's raw material.",
 'smart waste bins': 'Supporting smart waste bins will optimize garbage collection routes, saving fuel and ensuring that city streets remain clean and tidy.',
 'compostable cutlery research': 'By funding compostable cutlery research, the government can help eliminate the billions of single-use plastic forks and spoons that end up in oceans.',
 'biodegradable sensor networks': 'Investing in biodegradable sensor networks will allow farmers to monitor soil conditions without leaving behind plastic pollution in their fields.',
 'public environmental monitoring': 'Supporting public environmental monitoring will provide citizens with transparent and accurate data about the air and water quality in their area.',
 'citizen air sensors': 'By distributing citizen air sensors, the government can crowdsource data to identify specific neighborhoods that are suffering from high pollution.',
 'noise pollution barriers': 'Investing in noise pollution barriers will protect residents living near busy highways from the health risks associated with constant loud traffic.',
 'light pollution reduction': 'Supporting light pollution reduction will help restore the natural night sky while protecting the migratory patterns of birds and insects.',
 'dark sky preserves': 'By creating dark sky preserves, the government can protect our view of the stars and support scientific astronomy and astro-tourism.'}

# %%
gain_2 = {'renewable energy': 'Allocating resources to renewable energy will foster energy independence while significantly lowering the carbon footprint of the national power grid.',
 'public transportation': 'Supporting public transportation will enhance urban connectivity and reduce the overall environmental impact of daily commuting for millions of citizens.',
 'mental health services': 'By increasing funding for mental health services, society can improve personal resilience and reduce the social strain of untreated psychological conditions.',
 'urban green spaces': 'Investing in urban green spaces will mitigate city heat effects and offer residents vital areas for physical exercise and relaxation.',
 'wildlife conservation': 'Promoting wildlife conservation will protect endangered species and ensure that critical natural habitats remain intact for future generations to enjoy.',
 'high-speed rail': 'Developing high-speed rail will modernize the national transit network and provide a low-emission alternative to short-haul commercial airline flights.',
 'universal childcare': 'By increasing funding for universal childcare, the government enables greater workforce participation among parents and supports early childhood learning.',
 'affordable housing': 'Investing in affordable housing will stabilize local communities and provide low-income families with a secure foundation for economic success.',
 'rural broadband access': 'Supporting rural broadband access will empower remote students and businesses by providing the high-speed connectivity required in the modern era.',
 'clean water infrastructure': 'By increasing funding for clean water infrastructure, the state protects public health by ensuring consistent access to uncontaminated drinking water.',
 'teacher training programs': 'Investing in teacher training programs will elevate the standard of classroom instruction and better prepare students for specialized career paths.',
 'vocational education': 'Supporting vocational education will bridge the skills gap by training a new generation of technicians for essential trade industries.',
 'carbon capture technology': 'By increasing funding for carbon capture technology, the government can actively reduce atmospheric CO2 levels and meet ambitious climate goals.',
 'cybersecurity defense': 'Investing in cybersecurity defense will shield national interests from digital espionage and maintain the integrity of private citizen information.',
 'early childhood development': 'Prioritizing early childhood development will yield high long-term returns by improving the cognitive and social abilities of the youngest citizens.',
 'sustainable agriculture': 'Supporting sustainable agriculture will enhance food security while reducing the chemical runoff that often harms local river systems.',
 'public health research': 'By increasing funding for public health research, scientists can develop the vaccines and treatments needed to combat emerging global threats.',
 'disaster resilient infrastructure': 'Investing in disaster resilient infrastructure will minimize property damage and save countless lives during increasingly frequent extreme weather events.',
 'smart city technology': 'Supporting smart city technology will streamline municipal operations and improve the efficiency of public utilities through data-driven management.',
 'space exploration': 'By increasing funding for space exploration, the government drives high-tech innovation and inspires students to pursue careers in science.',
 'quantum computing research': 'Investing in quantum computing research will unlock unprecedented processing speeds and secure a national lead in the global technology race.',
 'elderly care facilities': 'Supporting elderly care facilities will provide the aging population with professional medical attention and a comfortable environment for their retirement.',
 'ocean plastic removal': 'By increasing funding for ocean plastic removal, we can safeguard marine biodiversity and reduce the chemical contamination of our oceans.',
 'forest restoration': 'Investing in forest restoration will bolster natural carbon sequestration and help recover lost ecosystems in formerly deforested regions.',
 'youth mentorship programs': 'Supporting youth mentorship programs will provide positive role models for teenagers and encourage them to pursue higher education and careers.',
 'domestic manufacturing': 'By increasing funding for domestic manufacturing, the country can revitalize its industrial base and create thousands of stable, high-paying jobs.',
 'green hydrogen production': 'Investing in green hydrogen production will offer a clean fuel source for heavy transport and help eliminate industrial carbon emissions.',
 'literacy initiatives': 'Supporting literacy initiatives will improve the functional reading levels of the population and increase the overall employability of the workforce.',
 'veteran support services': 'By increasing funding for veteran support services, the government honors those who served by providing comprehensive mental and physical healthcare.',
 'electric vehicle charging': 'Investing in electric vehicle charging will accelerate the transition to zero-emission cars and reduce the public health risks of smog.',
 'biodiversity protection': 'Supporting biodiversity protection will preserve the natural variety of life that is essential for discovering new medicines and foods.',
 'grid modernization': 'By increasing funding for grid modernization, we can create a smarter energy network capable of handling fluctuating renewable power inputs.',
 'small business grants': 'Investing in small business grants will stimulate local entrepreneurship and encourage the growth of innovative companies in small communities.',
 'maternal health care': 'Supporting maternal health care will ensure safer pregnancies and provide a healthy start for infants through better prenatal medical services.',
 'workforce retraining': 'By increasing funding for workforce retraining, the nation helps displaced employees find new roles in the growing green energy sector.',
 'emergency response systems': 'Investing in emergency response systems will sharpen the speed of first responders and improve survival rates during medical or fire crises.',
 'public library systems': 'Supporting public library systems will preserve free access to information and provide community members with a quiet place for study.',
 'pedestrian safety infrastructure': 'By increasing funding for pedestrian safety infrastructure, cities can reduce walking accidents and promote more active, healthy lifestyles for residents.',
 'organic farming subsidies': 'Investing in organic farming subsidies will lower the cost of healthy food and encourage agricultural practices that protect the soil.',
 'semiconductor production': 'Supporting semiconductor production will ensure that domestic industries have a reliable supply of the chips necessary for modern electronics.',
 'artificial intelligence ethics': 'By increasing funding for artificial intelligence ethics, we can prevent algorithmic bias and ensure that automation serves the public interest.',
 'bilingual education': 'Investing in bilingual education will prepare the youth for a globalized economy and improve the social integration of immigrant communities.',
 'waste-to-energy plants': 'Supporting waste-to-energy plants will turn municipal trash into a useful resource while significantly reducing the need for new landfills.',
 'social housing projects': 'By increasing funding for social housing projects, the state provides a vital safety net for individuals facing extreme economic hardship.',
 'preventative medicine': 'Investing in preventative medicine will lower long-term healthcare spending by identifying and treating health issues before they become severe.',
 'flood defense systems': 'Supporting flood defense systems will protect valuable property and critical infrastructure from the damaging effects of rising water levels.',
 'community college funding': 'By increasing funding for community college funding, the government expands access to higher education for students from all financial backgrounds.',
 'renewable heating systems': 'Investing in renewable heating systems will assist homeowners in moving away from expensive fossil fuels while lowering residential carbon emissions.',
 'precision medicine': 'Supporting precision medicine will revolutionize healthcare by providing tailored treatments based on the unique genetic profiles of individual patients.',
 'coastal erosion prevention': 'By increasing funding for coastal erosion prevention, we can maintain beautiful beaches and protect seaside towns from the encroaching ocean.',
 'adult education centers': 'Investing in adult education centers will allow citizens to continuously upgrade their skills and remain relevant in the modern workforce.',
 'rare disease research': 'Supporting rare disease research will provide breakthroughs for patients who currently lack effective treatments for their specific medical conditions.',
 'national park maintenance': 'Investing in national park maintenance will protect our natural wonders and ensure that tourism continues to support local rural economies.',
 'solar panel manufacturing': 'Supporting solar panel manufacturing will lower the price of clean energy while creating thousands of manufacturing jobs for local workers.',
 'clean air initiatives': 'By increasing funding for clean air initiatives, the public can enjoy better health outcomes and a higher overall quality of life.',
 'prison rehabilitation programs': 'Investing in prison rehabilitation programs will lower crime rates by giving formerly incarcerated individuals the tools to succeed in society.',
 'drought resistant crops': 'Supporting drought resistant crops will safeguard the national food supply as agricultural regions experience more frequent and severe water shortages.',
 'high-tech startups': 'By increasing funding for high-tech startups, the state fosters an environment where new ideas can grow into major economic drivers.',
 'marine protected areas': 'Investing in marine protected areas will allow ocean life to thrive and protect the long-term viability of the commercial fishing industry.',
 'after-school programs': 'Supporting after-school programs will keep children in a safe environment while providing them with additional academic and social enrichment.',
 'geothermal energy': 'By increasing funding for geothermal energy, we can tap into a constant source of renewable power located directly beneath the earth.',
 'biofuel development': 'Investing in biofuel development will provide a renewable fuel source that can utilize existing engines to reduce overall carbon output.',
 'language preservation': "Supporting language preservation will maintain the world's cultural heritage and help indigenous communities pass down their unique traditional knowledge.",
 'public arts programs': 'By increasing funding for public arts programs, the government fosters a more vibrant culture and supports the creative economy in cities.',
 'infectious disease surveillance': 'Investing in infectious disease surveillance will ensure that the public is warned of potential health threats before they reach pandemic levels.',
 'cycling infrastructure': 'Supporting cycling infrastructure will provide a low-cost transportation option that reduces both traffic congestion and harmful urban air pollution.',
 'desalination plants': 'By increasing funding for desalination plants, arid regions can create a reliable source of drinking water that is independent of rainfall.',
 'solid waste management': 'Investing in solid waste management will minimize environmental contamination and maximize the recovery of valuable materials from the waste stream.',
 'regenerative medicine': "Supporting regenerative medicine will lead to new therapies that use a patient's own cells to heal injuries and cure diseases.",
 'local food systems': 'By increasing funding for local food systems, we can shorten supply chains and provide residents with fresher, more nutritious produce.',
 'bridge repair projects': 'Investing in bridge repair projects will guarantee the safety of commuters and prevent the economic disruption caused by structural failures.',
 'special education resources': 'Supporting special education resources will empower students with different learning needs to succeed academically and live more independent lives.',
 'battery storage technology': 'By increasing funding for battery storage technology, the country can overcome the intermittency of solar and wind power on the grid.',
 'indigenous land management': 'Investing in indigenous land management will utilize centuries of ecological knowledge to protect forests and water sources more effectively.',
 'remote learning tools': 'Supporting remote learning tools will ensure that students in isolated areas have access to the same high-quality education as urban students.',
 'satellite communication': 'By increasing funding for satellite communication, the government can improve emergency response coordination and expand internet access to remote regions.',
 'water recycling systems': 'Investing in water recycling systems will alleviate the pressure on natural aquifers and provide a sustainable supply for industrial use.',
 'labor market transparency': 'Supporting labor market transparency will help job seekers find the best positions and ensure that employers pay fair, competitive wages.',
 'microgrid development': 'By increasing funding for microgrid development, local communities can maintain power even during major failures of the national electrical system.',
 'sustainable forestry': 'Investing in sustainable forestry will ensure that our timber needs are met without destroying the ecosystems that support forest wildlife.',
 'physical education': 'Supporting physical education will help reduce the long-term costs of public health by encouraging fitness among the younger generation.',
 'immunization programs': 'By increasing funding for immunization programs, the state can prevent the spread of contagious diseases and protect vulnerable populations.',
 'circular economy initiatives': 'Investing in circular economy initiatives will transform waste into a resource and encourage businesses to design more durable and recyclable products.',
 'homelessness prevention': 'Supporting homelessness prevention will provide at-risk individuals with the support they need to maintain stable housing and productive lives.',
 'tidal power': 'By increasing funding for tidal power, coastal nations can harness a predictable and clean energy source from the movement of the sea.',
 'urban farming': 'Investing in urban farming will turn vacant city lots into productive green spaces that provide fresh food for local residents.',
 'citizen science projects': 'Supporting citizen science projects will allow the public to contribute to important research while increasing their understanding of environmental issues.',
 'dam safety': 'By increasing funding for dam safety, the government can prevent catastrophic floods and ensure the continued reliability of hydroelectric power.',
 'public square renovation': 'Investing in public square renovation will create vibrant social hubs that boost local commerce and enhance the sense of community.',
 'space debris removal': 'Supporting space debris removal will safeguard the satellites that our modern communication and GPS systems depend on every single day.',
 'advanced robotics': 'By increasing funding for advanced robotics, industries can improve precision and safety while freeing humans from the most dangerous jobs.',
 'community health clinics': 'Investing in community health clinics will provide accessible medical care to low-income neighborhoods and reduce the pressure on hospital emergency rooms.',
 'historic preservation': 'Supporting historic preservation will protect our architectural heritage and educate the public about the events that shaped our national identity.',
 'food security programs': 'By increasing funding for food security programs, the state ensures that every citizen has consistent access to enough healthy food.',
 'public broadcasting': 'Investing in public broadcasting will provide the citizenry with educational content and unbiased news that is free from commercial influence.',
 'peatland restoration': 'Supporting peatland restoration will prevent the release of ancient carbon and protect the unique plant species that grow in bogs.',
 'stem cell research': 'By increasing funding for stem cell research, we can discover new ways to treat paralysis and other previously incurable medical conditions.',
 'district heating': 'Investing in district heating will offer an efficient and cost-effective way to warm entire neighborhoods using centralized clean energy sources.',
 'migrant integration services': 'Supporting migrant integration services will facilitate the social and economic inclusion of new residents into the national fabric.',
 'energy efficient appliances': 'By increasing funding for energy efficient appliances, the government helps citizens save money while reducing the total load on the grid.',
 'rural healthcare clinics': 'Investing in rural healthcare clinics will bring life-saving medical attention to people living in areas far from major metropolitan hospitals.',
 'national security technology': 'Supporting national security technology will give the country the tools needed to detect and neutralize modern threats before they strike.',
 'neighborhood revitalization': 'By increasing funding for neighborhood revitalization, we can improve property values and bring new life to previously distressed urban areas.',
 'online safety education': 'Investing in online safety education will protect children and seniors from digital predators and help everyone browse the web safely.',
 'sustainable fashion research': 'Supporting sustainable fashion research will help the apparel industry reduce its water usage and move away from toxic chemical dyes.',
 'park and ride': 'By increasing funding for park and ride, the city can encourage more commuters to use transit and reduce downtown traffic.',
 'industrial decarbonization': 'Investing in industrial decarbonization will assist heavy manufacturers in adopting the new technologies needed to eliminate their greenhouse gas emissions.',
 'pediatric care': 'Supporting pediatric care will ensure that children receive specialized medical treatment that is specifically tailored to their unique developmental needs.',
 'river cleanup operations': 'By increasing funding for river cleanup operations, we can restore the beauty of our waterways and protect the health of fish.',
 'weather forecasting systems': 'Investing in weather forecasting systems will provide farmers and emergency managers with the accurate data they need to prepare for storms.',
 'green building materials': 'Supporting green building materials will promote the construction of homes that are both environmentally friendly and healthier for the people living inside.',
 'soil health restoration': 'By increasing funding for soil health restoration, the government can help farmers grow more food while storing more carbon in the ground.',
 'public transit subsidies': 'Investing in public transit subsidies will lower the cost of commuting for the public and encourage a shift away from cars.',
 'aerospace engineering': 'Supporting aerospace engineering will lead to the development of quieter and more efficient planes that reduce the noise and carbon of flight.',
 'mental health apps': 'By increasing funding for mental health apps, the state provides a discreet and accessible way for individuals to seek psychological support.',
 'clean energy jobs': 'Investing in clean energy jobs will build a modern workforce and ensure that citizens are prepared for the high-tech green economy.',
 'oceanographic research': 'Supporting oceanographic research will help us better understand the role the sea plays in regulating the global climate and weather patterns.',
 'community gardens': 'By increasing funding for community gardens, the city can provide residents with a peaceful space to grow their own healthy food.',
 'disability access improvements': 'Investing in disability access improvements will ensure that our public buildings and transit systems are truly inclusive for all members of society.',
 'hydrogen fuel cells': 'Supporting hydrogen fuel cells will provide a powerful and clean energy solution for moving freight without the need for fossil fuels.',
 'carbon sequestration': 'By increasing funding for carbon sequestration, we can remove the emissions that have already been released into the atmosphere over past decades.',
 'anti-smoking campaigns': 'Investing in anti-smoking campaigns will significantly reduce the number of citizens suffering from preventable lung cancers and heart diseases.',
 'autonomous vehicle safety': 'Supporting autonomous vehicle safety will ensure that the future of self-driving transportation is reliable and protects the lives of all passengers.',
 'microchip design': 'By increasing funding for microchip design, the country can develop the specialized hardware needed for the next leap in artificial intelligence.',
 'youth sports facilities': 'Investing in youth sports facilities will provide young people with healthy outlets for their energy and teach them the value of teamwork.',
 'sustainable tourism': 'Supporting sustainable tourism will protect our natural beauty while ensuring that the economic benefits of travel reach local community members.',
 'wastewater treatment': 'By increasing funding for wastewater treatment, we can clean up our water supplies and prevent the spread of dangerous waterborne illnesses.',
 'nutrition assistance': 'Investing in nutrition assistance will ensure that children in low-income families have the healthy meals they need to grow and learn.',
 'reforestation projects': 'Supporting reforestation projects will help restore the natural air filters of our planet and provide new homes for various forest animals.',
 'advanced materials science': 'By increasing funding for advanced materials science, we can create the lighter and stronger components needed for the future of transportation.',
 'family planning services': 'Investing in family planning services will empower individuals to make informed choices about their reproductive health and the size of their families.',
 'cyber-physical systems': 'Supporting cyber-physical systems will enhance the coordination between software and hardware in our modern electrical grids and manufacturing plants.',
 'public records digitization': 'By increasing funding for public records digitization, the government can improve its efficiency and make historical documents easier for everyone to view.',
 'clean cooking fuels': 'Investing in clean cooking fuels will drastically improve the health of families who currently rely on smoky and dangerous indoor stoves.',
 'wildfire prevention': 'Supporting wildfire prevention will protect homes and wildlife by reducing the overgrowth that fuels the most intense and destructive forest fires.',
 'vaccine manufacturing': 'By increasing funding for vaccine manufacturing, the nation can secure its own supply of medicine and respond faster to future health crises.',
 'marine biology research': 'Investing in marine biology research will help us discover new species and find better ways to protect the health of our oceans.',
 'smart irrigation': 'Supporting smart irrigation will allow farmers to produce larger crops while using only the precise amount of water that the plants require.',
 'alternative protein research': 'By increasing funding for alternative protein research, we can develop new foods that are both delicious and better for the global environment.',
 'urban drainage systems': 'Investing in urban drainage systems will protect city streets and basements from the damaging effects of sudden and heavy tropical rainstorms.',
 'digital literacy training': 'Supporting digital literacy training will bridge the generational gap and ensure that all citizens can participate in the modern internet economy.',
 'biotechnology innovation': 'By increasing funding for biotechnology innovation, scientists can develop more resilient crops and new treatments for the most difficult human diseases.',
 'poverty alleviation': 'Investing in poverty alleviation will strengthen the middle class and ensure that every citizen has a fair chance to reach their potential.',
 'public safety equipment': 'Supporting public safety equipment will provide police and firefighters with the modern technology they need to keep our neighborhoods safe every day.',
 'heritage site protection': 'By increasing funding for heritage site protection, we can ensure that our most important cultural landmarks are preserved for future generations.',
 'sustainable aviation fuel': 'Investing in sustainable aviation fuel will help the airline industry reduce its environmental impact without requiring major changes to existing aircraft.',
 'green shipping lanes': 'Supporting green shipping lanes will protect our oceans by encouraging the use of cleaner fuels in the global maritime trade industry.',
 'low-carbon cement': 'By increasing funding for low-carbon cement, the government can help the construction industry build new cities while producing fewer greenhouse gases.',
 'integrated pest management': 'Investing in integrated pest management will allow farmers to protect their crops using natural methods that reduce the need for toxic pesticides.',
 'nuclear power plants': 'Supporting nuclear power plants will provide a reliable and carbon-free source of electricity that can support the national energy grid 24/7.',
 'universal basic income': 'By increasing funding for universal basic income, the state can provide a financial cushion that allows citizens to pursue new opportunities.',
 'high-density housing': 'Investing in high-density housing will make it easier for people to live near their jobs while reducing the need for cars.',
 'semiconductor research labs': 'Supporting semiconductor research labs will drive the innovation of smaller and faster computer chips that are vital for national security.',
 'pediatric mental health': 'By increasing funding for pediatric mental health, we can provide early support for children experiencing emotional or behavioral challenges at school.',
 'coastal levee systems': 'Investing in coastal levee systems will provide a critical line of defense for low-lying towns against the threat of rising sea levels.',
 'carbon tax infrastructure': 'Supporting carbon tax infrastructure will create a transparent system that encourages businesses to find innovative ways to reduce their total emissions.',
 'public Wi-Fi networks': 'By increasing funding for public Wi-Fi networks, the government ensures that students can complete their homework even if they lack home internet.',
 'rare earth mining': 'Investing in rare earth mining will reduce our dependence on foreign imports for the materials needed in smartphones and electric motors.',
 'sustainable textile production': 'Supporting sustainable textile production will encourage the use of recycled fibers and reduce the environmental damage caused by the clothing industry.',
 'recycled plastic roads': 'By increasing funding for recycled plastic roads, the state can find a productive use for plastic waste while building durable highways.',
 'hydrogen fueling stations': 'Investing in hydrogen fueling stations will make it possible for heavy trucks to drive long distances across the country without pollution.',
 'organic waste collection': 'Supporting organic waste collection will turn kitchen scraps into useful compost that can improve the health of our local community gardens.',
 'marine turbine arrays': 'By increasing funding for marine turbine arrays, we can generate a predictable stream of renewable energy from the constant flow of tides.',
 'smart electrical meters': 'Investing in smart electrical meters will help families understand their energy consumption patterns and find ways to save on their bills.',
 'public drone delivery': 'Supporting public drone delivery will significantly speed up the distribution of critical medicine and organs to hospitals in busy urban centers.',
 'quantum encryption tools': 'By increasing funding for quantum encryption tools, the government can ensure that national secrets remain safe from even the most powerful computers.',
 'vertical farming facilities': 'Investing in vertical farming facilities will bring fresh agriculture into the heart of the city, reducing the need for long-distance transport.',
 'urban canopy expansion': 'Supporting urban canopy expansion will create more shade in city streets and help to naturally filter pollutants out of the air.',
 'disaster warning apps': 'By increasing funding for disaster warning apps, the state can ensure that every citizen receives life-saving information before a storm arrives.',
 'high-tech vocational labs': 'Supporting high-tech vocational labs will give students the chance to learn on the same advanced equipment used by leading global manufacturers.',
 'bilingual signage systems': 'By increasing funding for bilingual signage systems, the government makes the city more welcoming and easier to navigate for international visitors.',
 'public water filtration': 'Investing in public water filtration will remove harmful microplastics and chemicals from our drinking water to protect the health of residents.',
 'migrant job training': 'Supporting migrant job training will ensure that new arrivals can quickly find work and contribute to the economic growth of the country.',
 'veteran housing vouchers': 'By increasing funding for veteran housing vouchers, we can ensure that every person who served our nation has a safe place to live.',
 'clean energy startups': 'Investing in clean energy startups will provide the early-stage capital needed to bring the next big green invention to the global market.',
 'electric bus fleets': 'Supporting electric bus fleets will lower city noise levels while ensuring that public transportation does not contribute to local air pollution.',
 'renewable cooling systems': 'By increasing funding for renewable cooling systems, the government can help large office buildings stay comfortable during summer without using fossil fuels.',
 'sustainable fishing gear': 'Investing in sustainable fishing gear will help prevent the accidental capture of endangered marine animals while supporting the livelihoods of local fishers.',
 'ocean thermal energy': 'Supporting ocean thermal energy will provide tropical island nations with a consistent source of clean electricity from the surrounding deep water.',
 'forest fire lookouts': 'By increasing funding for forest fire lookouts, we can catch small fires before they grow into massive blazes that threaten local towns.',
 'public data centers': 'Investing in public data centers will ensure that digital government services remain fast, secure, and under the control of the national citizenry.',
 'open science initiatives': 'Supporting open science initiatives will break down barriers to information and allow researchers everywhere to work together on global health challenges.',
 'community tool libraries': 'By increasing funding for community tool libraries, the government helps neighbors share the cost of equipment needed for home repairs and gardening.',
 'neighborhood tool sharing': 'Investing in neighborhood tool sharing will build social bonds between residents while reducing the total amount of waste from unused home equipment.',
 'specialized nursing education': 'Supporting specialized nursing education will ensure that our healthcare system has the experts needed to treat an aging and diverse population.',
 'rare mineral stockpiles': 'By increasing funding for rare mineral stockpiles, the nation can protect itself against sudden changes in the global supply of critical materials.',
 'advanced polymer research': 'Investing in advanced polymer research will lead to the development of plastics that break down safely in the environment after they are used.',
 'public compost facilities': 'Supporting public compost facilities will reduce the amount of organic waste sent to landfills and create rich soil for agricultural use.',
 'sustainable concrete development': 'By increasing funding for sustainable concrete development, the construction industry can find ways to build high-rise towers with far fewer carbon emissions.',
 'tidal surge barriers': 'Investing in tidal surge barriers will provide a long-term solution for protecting low-lying coastal cities from the risks of rising sea levels.',
 'autonomous shuttle loops': 'Supporting autonomous shuttle loops will provide a convenient and safe transportation option for passengers at major international airports and shopping centers.',
 'youth coding camps': 'By increasing funding for youth coding camps, we can ensure that children from all backgrounds have the skills to thrive in technology.',
 'urban waterway restoration': 'Investing in urban waterway restoration will improve the aesthetics of the city while creating new habitats for fish and local bird species.',
 'public charging docks': 'Supporting public charging docks for phones and laptops will ensure that citizens can stay connected even when they are on the move.',
 'smart traffic signals': 'By increasing funding for smart traffic signals, the city can reduce the time drivers spend waiting at red lights, saving time and fuel.',
 'industrial heat pumps': 'Investing in industrial heat pumps will allow chemical and food processing plants to operate using clean electricity instead of burning natural gas.',
 'methane leak detection': 'Supporting methane leak detection will identify the sources of one of the most powerful greenhouse gases so they can be fixed quickly.',
 'aquifer recharge systems': 'By increasing funding for aquifer recharge systems, the government can store excess rainwater underground for use during future periods of severe drought.',
 'sustainable irrigation tech': 'Investing in sustainable irrigation tech will help farmers grow more food while using less water, which is vital in our warming world.',
 'citizen science apps': 'Supporting citizen science apps will turn every smartphone user into a potential researcher who can help monitor local wildlife and pollution.',
 'public health laboratories': 'By increasing funding for public health laboratories, the country can maintain a state-of-the-art defense against new and dangerous viruses and bacteria.',
 'emergency surgical centers': 'Investing in emergency surgical centers will provide immediate and specialized care for victims of accidents or natural disasters when every second counts.',
 'rehabilitative sports programs': 'Supporting rehabilitative sports programs will help people recover from physical injuries through active participation in athletics and guided community social support.',
 'accessible playground equipment': 'By increasing funding for accessible playground equipment, the government ensures that children with mobility challenges can play alongside their peers in parks.',
 'sustainable livestock feed': 'Investing in sustainable livestock feed will reduce the amount of land needed for farming while lowering the greenhouse emissions from farm animals.',
 'precision forestry tools': 'Supporting precision forestry tools will allow foresters to manage woodlands with high accuracy to maximize both timber yield and carbon storage.',
 'biodiversity corridors': 'By increasing funding for biodiversity corridors, we can create safe pathways that allow animals to migrate safely between different protected forest areas.',
 'urban wetland preservation': 'Investing in urban wetland preservation will provide a natural way to clean up city stormwater while offering a home for migrating birds.',
 'public transit sensors': 'Supporting public transit sensors will give transit agencies the data they need to add more buses during the busiest times of day.',
 'renewable aviation research': 'By increasing funding for renewable aviation research, the government can help develop the electric and hydrogen planes of the future for travelers.',
 'clean steel manufacturing': 'Investing in clean steel manufacturing will transform an industry that is currently a major source of pollution into a clean, green sector.',
 'green ammonia production': 'Supporting green ammonia production will provide the shipping industry with a zero-carbon fuel and help farmers fertilize their fields more sustainably.',
 'sustainable brick making': 'By increasing funding for sustainable brick making, the government can encourage construction companies to use building materials that do not require fossil fuels.',
 'bio-based plastics': 'Investing in bio-based plastics will provide a sustainable alternative to traditional materials that often take centuries to break down in the environment.',
 'mycelium building materials': 'Supporting mycelium building materials will promote the use of fungi-based products that are compostable and require very little energy to produce locally.',
 'recycled aluminum plants': 'By increasing funding for recycled aluminum plants, the nation can save 95% of the energy normally required to produce new metal from ore.',
 'public art galleries': 'Investing in public art galleries will inspire the public and provide a venue for local artists to share their work with everyone.',
 'community radio stations': 'Supporting community radio stations will ensure that local news and independent music continue to have a voice on our national airwaves.',
 'youth orchestra programs': 'By increasing funding for youth orchestra programs, we can help young people develop discipline and a lifelong appreciation for the beauty of music.',
 'senior digital literacy': 'Investing in senior digital literacy will ensure that our older citizens are not left behind as more government services move onto the internet.',
 'migrant language classes': 'Supporting migrant language classes will help newcomers feel more at home and allow them to participate more fully in their local communities.',
 'refugee resettlement centers': 'By increasing funding for refugee resettlement centers, the government provides a safe place for people to rebuild their lives after fleeing from conflict.',
 'public swimming pools': 'Investing in public swimming pools will provide a low-cost way for families to stay active and cool during the hot summer months.',
 'municipal fiber optics': 'Supporting municipal fiber optics will ensure that every small business has the internet speed it needs to compete in the global market.',
 'clean construction equipment': 'By increasing funding for clean construction equipment, we can reduce the exhaust and loud noise that currently disrupt neighborhoods during new developments.',
 'electric freight rail': 'Investing in electric freight rail will move goods across the country with far less energy and pollution than traditional diesel trucks or trains.',
 'autonomous delivery bots': 'Supporting autonomous delivery bots will make the delivery of small packages more efficient and reduce the number of large vans on city streets.',
 'sustainable packaging research': 'By increasing funding for sustainable packaging research, we can help eliminate the single-use plastics that are currently clogging our rivers and oceans.',
 'ocean acidification monitoring': 'Investing in ocean acidification monitoring will help us understand the impact of carbon on our seas and protect the future of seafood.',
 'coral reef restoration': 'Supporting coral reef restoration will protect the natural barriers that shelter our coastlines from storms and provide a home for marine life.',
 'mangrove forest protection': 'By increasing funding for mangrove forest protection, we can safeguard one of the most efficient natural systems for storing carbon on Earth.',
 'peatland rewetting projects': 'Investing in peatland rewetting projects will restore the natural water balance of bogs and prevent massive amounts of CO2 from being released.',
 'glacier preservation tech': "Supporting glacier preservation tech will help maintain the world's natural water towers and prevent the sudden rise of global sea levels.",
 'river flow sensors': 'By increasing funding for river flow sensors, the state can better manage irrigation for farms and provide earlier warnings for potential floods.',
 'public park toilets': 'Investing in public park toilets will make our green spaces more comfortable and accessible for families and elderly citizens for long visits.',
 'sidewalk repair programs': 'Supporting sidewalk repair programs will make it safer for everyone to walk and ensure that those using wheelchairs have smooth paths.',
 'accessible transit vans': 'By increasing funding for accessible transit vans, the government ensures that citizens with mobility challenges can always get to their medical appointments.',
 'electric ferry services': 'Investing in electric ferry services will provide a quiet and clean way to travel across rivers and bays without any tailpipe emissions.',
 'sustainable port infrastructure': 'Supporting sustainable port infrastructure will help the shipping industry go green while ensuring that international trade continues to flow smoothly and safely.',
 'green hydrogen storage': 'By increasing funding for green hydrogen storage, we can save excess solar and wind power for use during the cold winter months.',
 'solid state batteries': 'Investing in solid state batteries will lead to more reliable energy storage that is safer and more powerful than current lithium-ion technology.',
 'modular reactor design': 'Supporting modular reactor design will allow the country to build safe nuclear power plants more quickly and at a lower total cost.',
 'fusion energy prototypes': 'By increasing funding for fusion energy prototypes, the government is investing in a potential source of nearly limitless and completely clean power.',
 'space-based solar power': 'Investing in space-based solar power would allow us to collect energy from the sun 24 hours a day and beam it home.',
 'lunar base research': 'Supporting lunar base research will allow scientists to test new technologies on the moon that could eventually be used to help humans.',
 'asteroid mining policy': 'By increasing funding for asteroid mining policy, the state can prepare for a future where we gather essential minerals from beyond our world.',
 'satellite internet arrays': 'Investing in satellite internet arrays will ensure that even the most remote schools in the country have a fast and reliable connection.',
 'hypersonic travel research': 'Supporting hypersonic travel research will help develop the next generation of flight technology that could connect any two cities in hours.',
 'nanotechnology safety labs': 'By increasing funding for nanotechnology safety labs, the government ensures that we can enjoy the benefits of new materials without any risks.',
 'synthetic biology ethics': 'Investing in synthetic biology ethics will create a safe framework for designing new medicines and crops that are healthy and strictly regulated.',
 'genomic sequencing centers': 'Supporting genomic sequencing centers will allow doctors to find the best medicine for each patient based on their own unique genetic code.',
 'personalized nutrition programs': 'By increasing funding for personalized nutrition programs, we can help people eat the right foods to stay healthy and avoid chronic illness.',
 'preventative dental care': 'Investing in preventative dental care will help children avoid painful cavities and lower the long-term cost of dental surgery for all families.',
 'mobile health vans': 'Supporting mobile health vans will bring basic medical checkups and vaccinations directly to neighborhoods that do not have a local clinic nearby.',
 'community birth centers': 'By increasing funding for community birth centers, the government provides mothers with a safe and comfortable environment to give birth with expert care.',
 'palliative care units': 'Investing in palliative care units will ensure that patients at the end of their lives are treated with the utmost respect and compassion.',
 'mental health crisis': 'Supporting mental health crisis response will ensure that people in emotional distress receive help from trained medical professionals rather than the police.',
 'substance abuse counseling': 'By increasing funding for substance abuse counseling, we can help people recover from addiction and become healthy, productive members of their local communities.',
 'homeless shelter beds': 'Supporting homeless shelter beds will provide a safe place for people to sleep while they work with social services to find permanent homes.',
 'domestic violence refuges': 'By increasing funding for domestic violence refuges, the state provides a vital safety net for individuals who need to escape dangerous home situations.',
 'foster care support': 'Investing in foster care support will ensure that the children in our care have the emotional and financial resources they need to thrive.',
 'adoption assistance programs': 'Supporting adoption assistance programs will make it easier for families to provide a permanent and loving home for children who need one.',
 'early literacy kits': 'By increasing funding for early literacy kits, the government can help parents start teaching their children to love reading from the very beginning.',
 'STEM kits for schools': 'Investing in STEM kits for schools will give every student the chance to learn about science and technology through fun and interesting experiments.',
 'dual-enrollment scholarships': 'Supporting dual-enrollment scholarships will help high school students get a head start on college while saving their families money on tuition costs.',
 'teacher salary subsidies': 'By increasing funding for teacher salary subsidies, we can show our educators how much we value their hard work in the national classroom.',
 'school meal programs': 'Investing in school meal programs will ensure that no child has to sit through a class while they are feeling hungry or tired.',
 'student debt relief': 'Supporting student debt relief will allow young workers to buy homes and start families without the burden of massive monthly loan payments.',
 'financial literacy classes': 'By increasing funding for financial literacy classes, the government empowers citizens to make smart decisions about their savings and their future retirement.',
 'civic education programs': 'Investing in civic education programs will help the next generation understand their rights and the importance of participating in our national democratic process.',
 'adult retraining grants': 'Supporting adult retraining grants will give workers the financial help they need to go back to school and learn a brand-new trade.',
 'apprenticeship tax credits': 'By increasing funding for apprenticeship tax credits, the government encourages businesses to hire and train young people for highly skilled and stable jobs.',
 'small farm equipment': 'Investing in small farm equipment will help family farmers work their land more efficiently and bring healthy food to our local tables.',
 'local farmers markets': 'Supporting local farmers markets will provide a place for residents to buy fresh food while supporting the hard-working growers in our area.',
 'urban beekeeping initiatives': 'By increasing funding for urban beekeeping initiatives, we can help improve the pollination of our city gardens and protect the global honeybee population.',
 'native wildflower meadows': 'Investing in native wildflower meadows will provide a beautiful home for butterflies and bees while reducing the cost of mowing public park land.',
 'pollinator habitat grants': 'Supporting pollinator habitat grants will encourage people to turn their backyards into safe spaces for the insects that help our food grow.',
 'invasive species removal': 'By increasing funding for invasive species removal, the government can protect our local forests and rivers from plants and animals that do not belong.',
 'soil carbon testing': 'Investing in soil carbon testing will help us understand how to farm in a way that stores carbon and helps fight climate change.',
 'water desalinization tech': 'Supporting water desalinization tech will ensure that we have enough drinking water even during the most severe and long-lasting droughts in history.',
 'greywater recycling systems': 'By increasing funding for greywater recycling systems, the state can help citizens use their sink and shower water to keep their gardens green.',
 'smart water valves': 'Investing in smart water valves will help cities find and fix leaks in the public pipes before they waste millions of gallons of water.',
 'public shower facilities': 'Supporting public shower facilities will provide a basic and important health service for our neighbors who are currently living on the city streets.',
 'urban cooling centers': 'By increasing funding for urban cooling centers, we can provide a safe and air-conditioned place for the elderly during very hot summer days.',
 'weatherization grant programs': 'Investing in weatherization grant programs will help families keep their homes warm in the winter while using much less electricity and natural gas.',
 'energy audit services': 'Supporting energy audit services will help people find exactly where their homes are losing heat so they can make the right repairs.',
 'low-interest green loans': 'By increasing funding for low-interest green loans, the government makes it much more affordable for every family to switch to clean solar energy.',
 'community land trusts': 'Investing in community land trusts will help keep the price of land low so that more people can afford to buy their own homes.',
 'cooperative housing models': 'Supporting cooperative housing models will give people a new and affordable way to live together in a building that they own together.',
 'rent control administration': 'By increasing funding for rent control administration, the government can protect families from being forced out of their homes by high price increases.',
 'public zoning reform': 'Investing in public zoning reform will make it easier for builders to create the different types of housing that our growing communities need.',
 'neighborhood safety patrols': 'Supporting neighborhood safety patrols will provide a friendly and visible presence that makes everyone feel safer when they are walking home at night.',
 'de-escalation training programs': 'By increasing funding for de-escalation training programs, we can help our police officers solve problems with words and avoid using any physical force.',
 'body-worn cameras': 'Investing in body-worn cameras will build trust between the police and the community by showing exactly what happens during every single interaction in public.',
 'forensic science labs': 'Supporting forensic science labs will give our justice system the tools it needs to use modern DNA evidence to solve crimes correctly.',
 'judicial case management': 'By increasing funding for judicial case management, the government can make the court system faster so that people do not have to wait.',
 'legal aid services': 'Investing in legal aid services will ensure that everyone has a lawyer to help them with important things like housing or family issues.',
 'public defender funding': 'Supporting public defender funding will protect the right to a fair trial for every person, even if they do not have any money.',
 'restorative justice centers': 'By increasing funding for restorative justice centers, we can help people who have done something wrong learn from their mistakes and make things right.',
 'victim compensation funds': 'Investing in victim compensation funds will provide financial help to people who have been hurt by a crime so they can start over.',
 'anti-corruption task forces': 'Supporting anti-corruption task forces will ensure that our government officials are always working for the public and following the rules for everyone.',
 'election security systems': 'By increasing funding for election security systems, we can protect our democracy and make sure that every single vote is counted correctly and safely.',
 'secure voting tech': 'Investing in secure voting tech will make it easier and safer for every citizen to cast their ballot during the next big election.',
 'government transparency portals': 'Supporting government transparency portals will allow any citizen to go online and see exactly how the government is using their tax money today.',
 'open data APIs': 'By increasing funding for open data APIs, the government helps developers create new apps that make it easier to use public transportation or parks.',
 'public records archives': 'Investing in public records archives will ensure that the history of our nation and our families is kept safe for hundreds of years.',
 'cultural heritage digitization': 'Supporting cultural heritage digitization will allow students to see our national treasures and historical photos from any computer in any school across the country.',
 'indigenous language schools': "By increasing funding for indigenous language schools, we can help native communities keep their beautiful and ancient languages alive for their children's children.",
 'traditional craft preservation': 'Investing in traditional craft preservation will help local artists keep the skills of their ancestors alive while creating beautiful and unique handmade products.',
 'public sculpture commissions': 'Supporting public sculpture commissions will make our city parks more interesting and provide our local artists with a way to share their vision.',
 'community mural projects': 'By increasing funding for community mural projects, we can turn ugly city walls into colorful paintings that tell the story of our local neighborhoods.',
 'youth theater grants': 'Investing in youth theater grants will give our children a fun way to learn about acting and build the confidence to speak in public.',
 'local film incentives': 'Supporting local film incentives will bring movie companies to our town, which creates jobs for local actors and helps our small local businesses grow.',
 'sustainable tourism boards': 'By increasing funding for sustainable tourism boards, the government can help our town attract visitors who will respect our environment and our local culture.',
 'national trail systems': 'Investing in national trail systems will give every citizen a place to walk, run, or bike through the most beautiful parts of the country.',
 'mountain bike paths': 'Supporting mountain bike paths will give people an exciting way to exercise outdoors while bringing new visitors to our beautiful mountain towns today.',
 'accessible hiking trails': 'Investing in accessible hiking trails will make it possible for people in wheelchairs to enjoy the fresh air and beauty of the forest.',
 'urban beach maintenance': 'Supporting urban beach maintenance will keep our city sand clean and the water safe for everyone to swim in during the summer months.',
 'public pier repair': 'By increasing funding for public pier repair, we can keep our coastal landmarks safe for families to walk on and enjoy the view.',
 'riverfront boardwalks': 'Investing in riverfront boardwalks will create a beautiful path for people to enjoy the water while helping our local shops and restaurants grow.',
 'floating solar farms': 'Supporting floating solar farms will generate clean electricity from the sun without using up any of the land needed for our local farms.',
 'wave energy converters': 'By increasing funding for wave energy converters, we can turn the constant power of the ocean waves into clean electricity for our coastal towns.',
 'micro-hydro turbines': 'Investing in micro-hydro turbines will provide a clean and steady source of electricity for small mountain villages that live near fast-flowing mountain streams.',
 'kinetic floor tiling': 'Supporting kinetic floor tiling in our busy train stations will turn the footsteps of thousands of people into a source of clean electricity.',
 'waste heat recovery': 'By increasing funding for waste heat recovery, our factories can catch the hot air they usually lose and use it to save energy.',
 'carbon-neutral glass production': 'Investing in carbon-neutral glass production will help us make the windows for our new homes without hurting the environment or the local air quality.',
 'sustainable rubber research': 'Supporting sustainable rubber research will help us find a way to make car tires from plants instead of using chemicals made from oil.',
 'bio-solvent development': 'By increasing funding for bio-solvent development, the government can help industries use cleaning chemicals that are made from natural plants and are safe.',
 'green chemistry labs': 'Investing in green chemistry labs will help scientists find new ways to make our medicines and products without creating any toxic waste today.',
 'circular textile hubs': 'Supporting circular textile hubs will allow our communities to turn old shirts and pants into new clothes, which reduces the amount of trash.',
 'reclaimed wood markets': 'By increasing funding for reclaimed wood markets, we can use old wood from broken barns to build beautiful new furniture and save our forests.',
 'industrial symbiosis parks': "Investing in industrial symbiosis parks will help different companies work together so that one company can use another company's waste to make products.",
 'smart waste bins': 'Supporting smart waste bins will tell the city exactly when they are full so that garbage trucks only drive when they really need to.',
 'compostable cutlery research': 'By increasing funding for compostable cutlery research, we can make forks and spoons that turn into soil instead of sitting in the ocean.',
 'biodegradable sensor networks': 'Investing in biodegradable sensor networks will allow our farmers to check on their soil using tiny tools that will just disappear into the ground.',
 'public environmental monitoring': 'Supporting public environmental monitoring will give every citizen the power to go online and see the quality of the air in their neighborhood.',
 'citizen air sensors': 'By increasing funding for citizen air sensors, the government can help residents track pollution near schools and find ways to make the air cleaner.',
 'noise pollution barriers': 'Investing in noise pollution barriers will make the homes near our busy highways much quieter and more peaceful for the families living there now.',
 'light pollution reduction': 'Supporting light pollution reduction will help us see the stars at night while making sure that birds can find their way during migration.',
 'dark sky preserves': 'By increasing funding for dark sky preserves, the government can protect our most beautiful views of the night sky for our children to enjoy.'}

# %%
loss_1 = {'renewable energy': 'Neglecting renewable energy will result in a continued reliance on volatile fossil fuel markets and higher levels of atmospheric pollution.',
 'public transportation': 'Failing to invest in public transportation will lead to increased urban congestion and restricted economic mobility for citizens without personal vehicles.',
 'mental health services': 'Without support for mental health services, communities will suffer from higher rates of untreated trauma and significant loss of economic productivity.',
 'urban green spaces': 'Ignoring urban green spaces could result in deteriorating air quality and a lack of essential cooling areas within dense metropolitan regions.',
 'wildlife conservation': 'Disregarding wildlife conservation will lead to the irreversible loss of biodiversity and the collapse of ecosystems that sustain human life.',
 'high-speed rail': 'Failing to fund high-speed rail means the nation will remain dependent on carbon-intensive air travel and inefficient highway systems for regional transit.',
 'universal childcare': 'Without support for universal childcare, many skilled parents will be forced out of the workforce, hindering overall national economic development.',
 'affordable housing': 'Neglecting affordable housing will exacerbate the national homelessness crisis and increase the financial strain on low-income working families.',
 'rural broadband access': 'By overlooking rural broadband access, the government allows the digital divide to widen, isolating remote populations from the global economy.',
 'clean water infrastructure': 'Failing to maintain clean water infrastructure risks the contamination of the public supply and the spread of preventable waterborne illnesses.',
 'teacher training programs': 'Without support for teacher training programs, the quality of education will decline, leaving the next generation unprepared for modern workplace challenges.',
 'vocational education': 'Ignoring vocational education will result in a critical shortage of skilled tradespeople needed to maintain and build essential national infrastructure.',
 'carbon capture technology': 'Failing to invest in carbon capture technology makes it increasingly difficult for heavy industries to meet necessary global emissions reduction targets.',
 'cybersecurity defense': 'Without support for cybersecurity defense, critical national infrastructure remains highly vulnerable to debilitating digital attacks and foreign state espionage.',
 'early childhood development': 'Neglecting early childhood development could result in long-term social inequality and higher costs for remedial education and corrective social services.',
 'sustainable agriculture': 'Failing to fund sustainable agriculture will lead to rapid soil depletion and a significant threat to long-term national food security.',
 'public health research': 'Without support for public health research, society remains defenseless against emerging viral threats and lacks the tools to cure chronic diseases.',
 'disaster resilient infrastructure': 'Ignoring disaster resilient infrastructure will cause natural catastrophes to become far more deadly and exponentially more expensive to recover from.',
 'smart city technology': 'Failing to invest in smart city technology will result in inefficient urban resource allocation and increasingly outdated municipal management systems.',
 'space exploration': 'Without support for space exploration, the nation risks falling behind in scientific innovation and losing its lead in aerospace technology.',
 'quantum computing research': 'Neglecting quantum computing research will result in a loss of technological sovereignty and leave national encryption systems vulnerable to future threats.',
 'elderly care facilities': 'Failing to fund elderly care facilities will leave an aging population without proper medical support and overwhelm family caregivers.',
 'ocean plastic removal': 'Without support for ocean plastic removal, marine ecosystems will continue to suffocate under the weight of non-biodegradable chemical waste.',
 'forest restoration': 'Ignoring forest restoration will accelerate the loss of natural carbon sinks and lead to the extinction of numerous woodland species.',
 'youth mentorship programs': 'Failing to invest in youth mentorship programs could result in higher crime rates and lower graduation numbers among at-risk teenagers.',
 'domestic manufacturing': 'Without support for domestic manufacturing, the nation remains dangerously dependent on foreign supply chains for essential medical and industrial goods.',
 'green hydrogen production': 'Neglecting green hydrogen production will prevent the decarbonization of heavy shipping and steel industries that cannot rely solely on electricity.',
 'literacy initiatives': 'Failing to fund literacy initiatives will leave a significant portion of the population unable to navigate the modern job market successfully.',
 'veteran support services': 'Without support for veteran support services, those who served the country may face higher risks of homelessness and untreated psychological trauma.',
 'electric vehicle charging': 'Ignoring electric vehicle charging will stall the adoption of clean cars and keep the nation dependent on expensive imported petroleum.',
 'biodiversity protection': 'Failing to invest in biodiversity protection will trigger the collapse of natural systems that provide pollination and essential climate regulation.',
 'grid modernization': 'Without support for grid modernization, the electrical network will remain prone to frequent blackouts and unable to handle renewable energy.',
 'small business grants': 'Neglecting small business grants will lead to economic stagnation and the erosion of local competition within the national marketplace.',
 'maternal health care': 'Failing to fund maternal health care will lead to higher infant mortality rates and preventable complications during pregnancy and childbirth.',
 'workforce retraining': 'Without support for workforce retraining, millions of employees will be left behind as automation and artificial intelligence reshape the economy.',
 'emergency response systems': 'Ignoring emergency response systems will result in longer dispatch times and a higher number of preventable deaths during critical incidents.',
 'public library systems': 'Failing to invest in public library systems will deny low-income citizens free access to educational materials and vital community resources.',
 'pedestrian safety infrastructure': 'Without support for pedestrian safety infrastructure, urban areas will remain dangerous for walkers and see high rates of traffic-related fatalities.',
 'organic farming subsidies': 'Neglecting organic farming subsidies will allow the continued use of toxic pesticides that harm both the environment and public health.',
 'semiconductor production': 'Failing to fund semiconductor production will leave the national tech industry at the mercy of unpredictable global supply chain disruptions.',
 'artificial intelligence ethics': 'Without support for artificial intelligence ethics, the development of new software may lead to widespread bias and social discrimination.',
 'bilingual education': 'Ignoring bilingual education will result in a workforce that is less capable of competing in an increasingly interconnected global economy.',
 'waste-to-energy plants': 'Failing to invest in waste-to-energy plants will lead to overcrowded landfills and the continued release of harmful methane gas.',
 'social housing projects': 'Without support for social housing projects, the most vulnerable citizens will remain trapped in a cycle of housing instability and poverty.',
 'preventative medicine': 'Neglecting preventative medicine will place an unsustainable financial burden on the healthcare system as chronic diseases go undetected and untreated.',
 'flood defense systems': 'Failing to fund flood defense systems will leave coastal and riverside communities vulnerable to catastrophic property damage and loss of life.',
 'community college funding': 'Without support for community college funding, millions of students will be priced out of the education needed for middle-class careers.',
 'renewable heating systems': 'Ignoring renewable heating systems will force households to remain reliant on expensive fossil fuels for warmth during the winter months.',
 'precision medicine': "Failing to invest in precision medicine will delay the development of life-saving treatments that are tailored to an individual's unique biology.",
 'coastal erosion prevention': 'Without support for coastal erosion prevention, sea levels will continue to destroy valuable shoreline property and displace thousands of residents.',
 'adult education centers': 'Neglecting adult education centers will result in a stagnant labor pool that lacks the skills required for modern high-tech industries.',
 'rare disease research': 'Failing to fund rare disease research will leave millions of patients without hope for a cure or effective medical management.',
 'national park maintenance': 'Ignoring national park maintenance will lead to the degradation of protected wilderness areas and the loss of significant tourism revenue.',
 'solar panel manufacturing': 'Failing to invest in solar panel manufacturing will result in a loss of competitive advantage in the global green energy market.',
 'clean air initiatives': 'Without support for clean air initiatives, urban populations will suffer from higher rates of asthma and other chronic respiratory conditions.',
 'prison rehabilitation programs': 'Neglecting prison rehabilitation programs will lead to higher recidivism rates and the continued social cost of perpetual incarceration cycles.',
 'drought resistant crops': 'Failing to fund drought resistant crops will threaten the stability of the food supply as climate change alters traditional weather patterns.',
 'high-tech startups': 'Without support for high-tech startups, the national economy will lack the disruptive innovation necessary to compete with rising global powers.',
 'marine protected areas': 'Ignoring marine protected areas will allow overfishing to decimate fish stocks and destroy the health of our global oceans.',
 'after-school programs': 'Failing to invest in after-school programs will leave children without safe environments and hinder their academic and social development.',
 'geothermal energy': 'Without support for geothermal energy, the nation misses the opportunity to utilize a constant and clean source of baseload power.',
 'biofuel development': 'Neglecting biofuel development will keep the aviation and shipping sectors dependent on carbon-heavy fuels for the foreseeable future.',
 'language preservation': 'Failing to fund language preservation will lead to the extinction of unique cultural identities and the loss of ancient human knowledge.',
 'public arts programs': 'Without support for public arts programs, communities will become culturally hollow and lack the creative outlets necessary for social cohesion.',
 'infectious disease surveillance': 'Ignoring infectious disease surveillance will leave the population highly vulnerable to the rapid spread of undetected and deadly pathogens.',
 'cycling infrastructure': 'Failing to invest in cycling infrastructure will ensure that city streets remain dominated by polluting cars and dangerous for active commuters.',
 'desalination plants': 'Without support for desalination plants, arid regions will face severe water shortages that could trigger social unrest and economic decline.',
 'solid waste management': 'Neglecting solid waste management will result in toxic groundwater contamination and the accumulation of trash in natural environments.',
 'regenerative medicine': 'Failing to fund regenerative medicine will stall the development of therapies that could permanently repair damaged organs and tissues.',
 'local food systems': 'Without support for local food systems, communities will remain vulnerable to international supply chain shocks and higher food transportation costs.',
 'bridge repair projects': 'Ignoring bridge repair projects will lead to structural failures that disrupt national commerce and endanger the lives of daily travelers.',
 'special education resources': 'Failing to invest in special education resources will prevent students with disabilities from achieving their full academic and personal potential.',
 'battery storage technology': 'Without support for battery storage technology, the transition to renewable energy will be hindered by an inability to store power.',
 'indigenous land management': 'Neglecting indigenous land management will lead to the loss of traditional ecological wisdom that is vital for environmental sustainability.',
 'remote learning tools': 'Failing to fund remote learning tools will disadvantage students in isolated areas, further entrenching geographic and economic inequality.',
 'satellite communication': 'Without support for satellite communication, the nation will struggle to maintain global connectivity and monitor critical environmental changes effectively.',
 'water recycling systems': 'Ignoring water recycling systems will lead to the depletion of natural freshwater sources and increased competition for limited water supplies.',
 'labor market transparency': 'Failing to invest in labor market transparency will result in wage gaps and the inefficient matching of workers to available jobs.',
 'microgrid development': 'Without support for microgrid development, local communities will remain completely vulnerable to total power failure during large-scale grid outages.',
 'sustainable forestry': 'Neglecting sustainable forestry will lead to widespread deforestation and the loss of natural habitats that regulate our climate.',
 'physical education': 'Failing to fund physical education will contribute to rising obesity rates and higher long-term healthcare costs for the national budget.',
 'immunization programs': 'Without support for immunization programs, preventable diseases will return, threatening public safety and overwhelming the national healthcare infrastructure.',
 'circular economy initiatives': 'Ignoring circular economy initiatives will result in the rapid depletion of natural resources and the accumulation of toxic industrial waste.',
 'homelessness prevention': 'Failing to invest in homelessness prevention will force more individuals into emergency shelters, costing the taxpayer significantly more in the long run.',
 'tidal power': 'Without support for tidal power, the nation will fail to capture the immense and predictable clean energy potential of the ocean.',
 'urban farming': 'Neglecting urban farming will leave city dwellers dependent on distant food sources and increase the environmental cost of urban living.',
 'citizen science projects': 'Failing to fund citizen science projects will result in a lack of local environmental data and reduced public engagement with science.',
 'dam safety': 'Without support for dam safety, the surrounding communities face the catastrophic risk of structural failure and massive downstream flooding.',
 'public square renovation': 'Ignoring public square renovation will lead to the decay of urban social centers and the decline of local retail businesses.',
 'space debris removal': 'Failing to invest in space debris removal could result in the loss of critical satellites and the closure of orbital lanes.',
 'advanced robotics': 'Without support for advanced robotics, domestic industries will struggle to remain competitive against more automated and efficient global manufacturers.',
 'community health clinics': 'Neglecting community health clinics will leave low-income families without basic medical services, leading to worse health outcomes for the poor.',
 'historic preservation': 'Failing to fund historic preservation will result in the loss of cultural landmarks that define our national history and heritage.',
 'food security programs': 'Without support for food security programs, millions of citizens will continue to suffer from malnutrition and chronic hunger.',
 'public broadcasting': 'Ignoring public broadcasting will leave the public with fewer sources of unbiased news and high-quality educational content.',
 'peatland restoration': 'Failing to invest in peatland restoration will release massive amounts of carbon into the atmosphere, accelerating the pace of global warming.',
 'stem cell research': 'Without support for stem cell research, we will lose the chance to develop cures for paralysis and other debilitating diseases.',
 'district heating': 'Neglecting district heating will result in continued energy waste as individual buildings rely on inefficient and carbon-heavy heating systems.',
 'migrant integration services': 'Failing to fund migrant integration services will lead to social fragmentation and prevent new residents from contributing fully to society.',
 'energy efficient appliances': 'Without support for energy efficient appliances, household utility bills will stay high and the national grid will remain overstressed.',
 'rural healthcare clinics': 'Ignoring rural healthcare clinics will leave millions of remote citizens without access to life-saving medical treatment during emergencies.',
 'national security technology': 'Failing to invest in national security technology will leave the country exposed to modern threats from advanced weaponry and foreign intelligence.',
 'neighborhood revitalization': 'Without support for neighborhood revitalization, neglected urban areas will continue to suffer from high crime and persistent economic decline.',
 'online safety education': 'Neglecting online safety education will leave children and seniors highly vulnerable to digital fraud, bullying, and predatory behavior.',
 'sustainable fashion research': 'Failing to fund sustainable fashion research will allow the clothing industry to remain a top polluter of our global water supply.',
 'park and ride': 'Without support for park and ride facilities, city centers will remain choked with traffic and high levels of vehicle exhaust.',
 'industrial decarbonization': 'Ignoring industrial decarbonization will prevent the nation from meeting its climate commitments and lead to long-term environmental degradation.',
 'pediatric care': 'Failing to invest in pediatric care will lead to long-term health complications for children and higher medical costs for the state.',
 'river cleanup operations': 'Without support for river cleanup operations, waterways will remain toxic, destroying local ecosystems and threatening the quality of drinking water.',
 'weather forecasting systems': 'Neglecting weather forecasting systems will result in inaccurate storm warnings and a higher risk of loss of life during disasters.',
 'green building materials': 'Failing to fund green building materials ensures that the construction industry remains a primary contributor to global carbon emissions.',
 'soil health restoration': 'Without support for soil health restoration, agricultural land will become less productive, leading to food price spikes and farm failures.',
 'public transit subsidies': 'Ignoring public transit subsidies will make commuting unaffordable for many, resulting in more cars and worse air quality in cities.',
 'aerospace engineering': 'Failing to invest in aerospace engineering will cause the national aviation industry to fall behind in the development of efficient technology.',
 'mental health apps': 'Without support for mental health apps, those in need of immediate psychological support may find no accessible resources during a crisis.',
 'clean energy jobs': 'Neglecting clean energy jobs will result in high unemployment as workers in traditional energy sectors find themselves without future skills.',
 'oceanographic research': 'Failing to fund oceanographic research will leave us ignorant of the changes occurring in the sea that directly impact global weather.',
 'community gardens': 'Without support for community gardens, urban residents will lose a vital source of fresh food and a place for social interaction.',
 'disability access improvements': 'Ignoring disability access improvements will continue to exclude millions of citizens from participating fully in public life and the economy.',
 'hydrogen fuel cells': 'Failing to invest in hydrogen fuel cells will prevent the development of zero-emission solutions for long-haul freight and heavy shipping.',
 'carbon sequestration': 'Without support for carbon sequestration, greenhouse gases will continue to accumulate in the atmosphere, driving dangerous levels of global warming.',
 'anti-smoking campaigns': 'Neglecting anti-smoking campaigns will result in higher rates of preventable lung cancer and an increased financial burden on hospitals.',
 'autonomous vehicle safety': 'Failing to fund autonomous vehicle safety will result in public distrust and more accidents as self-driving technology enters the market.',
 'microchip design': 'Without support for microchip design, the national electronics industry will struggle to keep pace with the rapid advancements of global competitors.',
 'youth sports facilities': 'Ignoring youth sports facilities will contribute to higher rates of childhood obesity and a lack of constructive community outlets for teenagers.',
 'sustainable tourism': 'Failing to invest in sustainable tourism will result in the destruction of natural landmarks and the loss of cultural heritage sites.',
 'wastewater treatment': 'Without support for wastewater treatment, communities face the direct threat of environmental pollution and the spread of dangerous pathogens.',
 'nutrition assistance': 'Neglecting nutrition assistance will leave children in low-income families without the fuel they need to grow and learn properly in school.',
 'reforestation projects': 'Failing to fund reforestation projects will result in the continued loss of forests that are essential for cleaning our air.',
 'advanced materials science': 'Without support for advanced materials science, the nation will be unable to develop the lighter and stronger components required for future industry.',
 'family planning services': 'Ignoring family planning services will lead to higher rates of unintended pregnancies and place a greater strain on public welfare systems.',
 'cyber-physical systems': 'Failing to invest in cyber-physical systems will leave national power plants and factories inefficient and vulnerable to mechanical or digital failures.',
 'public records digitization': 'Without support for public records digitization, government operations will remain slow and opaque, making it difficult for citizens to access information.',
 'clean cooking fuels': 'Neglecting clean cooking fuels will result in millions of avoidable deaths globally due to the toxic effects of indoor smoke inhalation.',
 'wildfire prevention': 'Failing to fund wildfire prevention will lead to more destructive forest fires that destroy property and release massive amounts of carbon.',
 'vaccine manufacturing': 'Without support for vaccine manufacturing, the nation will be unable to protect its citizens quickly during a future global health emergency.',
 'marine biology research': 'Ignoring marine biology research will prevent the discovery of new medical compounds and the protection of fragile underwater species.',
 'smart irrigation': 'Failing to invest in smart irrigation will lead to the massive waste of water in agriculture during times of extreme climate scarcity.',
 'alternative protein research': 'Without support for alternative protein research, the environmental impact of traditional meat production will continue to grow to unsustainable levels.',
 'urban drainage systems': 'Neglecting urban drainage systems will result in chronic street flooding and the destruction of expensive city infrastructure during heavy rain.',
 'digital literacy training': 'Failing to fund digital literacy training will leave the elderly and disadvantaged citizens unable to participate in a modern online society.',
 'biotechnology innovation': 'Without support for biotechnology innovation, we will miss out on the next generation of life-saving medicines and more resilient food crops.',
 'poverty alleviation': 'Ignoring poverty alleviation will lead to increased social instability and a lack of economic opportunity for the next generation of citizens.',
 'public safety equipment': 'Failing to invest in public safety equipment will leave first responders without the technology they need to save lives during emergencies.',
 'heritage site protection': "Without support for heritage site protection, the nation's most important historical locations will decay and be lost to time.",
 'sustainable aviation fuel': 'Neglecting sustainable aviation fuel will ensure that the airline industry remains a primary contributor to global environmental degradation.',
 'green shipping lanes': 'Failing to fund green shipping lanes will allow international trade to continue polluting the oceans and damaging the global climate.',
 'low-carbon cement': 'Without support for low-carbon cement, the construction of new infrastructure will remain a significant and avoidable source of carbon emissions.',
 'integrated pest management': 'Ignoring integrated pest management will lead to an overreliance on toxic chemicals that harm the environment and enter the food supply.',
 'nuclear power plants': 'Failing to invest in nuclear power plants will leave the grid without a reliable source of carbon-free baseload electricity for the future.',
 'universal basic income': 'Without support for universal basic income, millions may fall into extreme poverty as automation eliminates traditional entry-level jobs.',
 'high-density housing': 'Neglecting high-density housing will exacerbate urban sprawl and make city living unaffordable for the majority of the working population.',
 'semiconductor research labs': 'Failing to fund semiconductor research labs will result in a national dependence on foreign technology and a loss of digital sovereignty.',
 'pediatric mental health': 'Without support for pediatric mental health, children suffering from trauma will struggle in school and face greater challenges in adulthood.',
 'coastal levee systems': 'Ignoring coastal levee systems will leave low-lying coastal communities completely unprotected from the rising threat of catastrophic storm surges.',
 'carbon tax infrastructure': 'Failing to invest in carbon tax infrastructure prevents the market from accurately pricing the environmental damage caused by greenhouse gas emissions.',
 'public Wi-Fi networks': 'Without support for public Wi-Fi networks, low-income students will remain at a disadvantage due to a lack of home internet access.',
 'rare earth mining': "Neglecting rare earth mining will leave the nation's high-tech and defense industries dependent on potentially hostile foreign suppliers.",
 'sustainable textile production': 'Failing to fund sustainable textile production will allow the garment industry to continue being a leading source of global water pollution.',
 'recycled plastic roads': 'Without support for recycled plastic roads, billions of tons of waste will remain in landfills instead of serving a productive purpose.',
 'hydrogen fueling stations': 'Ignoring hydrogen fueling stations will make it impossible for zero-emission fuel cell trucks to replace polluting diesel vehicles on our highways.',
 'organic waste collection': 'Failing to invest in organic waste collection will result in the loss of valuable nutrients and increased methane emissions from landfills.',
 'marine turbine arrays': 'Without support for marine turbine arrays, the country will fail to capture the predictable and massive energy potential of ocean tides.',
 'smart electrical meters': 'Neglecting smart electrical meters will prevent consumers from managing their energy use effectively, leading to higher bills and grid stress.',
 'public drone delivery': 'Failing to fund public drone delivery could delay the transport of life-saving medical supplies to remote areas during critical emergencies.',
 'quantum encryption tools': 'Without support for quantum encryption tools, national secrets will become easily accessible to foreign powers using future quantum computers.',
 'vertical farming facilities': 'Ignoring vertical farming facilities will keep the food supply vulnerable to the disruptions caused by extreme weather and long-distance transport.',
 'urban canopy expansion': 'Failing to invest in urban canopy expansion will leave cities hotter and less livable as the climate continues to warm.',
 'disaster warning apps': 'Without support for disaster warning apps, citizens in the path of storms will lack the real-time information necessary to stay safe.',
 'high-tech vocational labs': 'Failing to fund high-tech vocational labs will leave students without the hands-on experience needed for modern, high-paying technical careers.',
 'bilingual signage systems': 'Without support for bilingual signage systems, public services will remain difficult for non-native residents and international visitors to navigate.',
 'public water filtration': 'Ignoring public water filtration will allow microplastics and chemical contaminants to persist in the drinking water, harming long-term public health.',
 'migrant job training': 'Failing to invest in migrant job training will lead to higher unemployment rates and slow the social and economic integration of newcomers.',
 'veteran housing vouchers': 'Without support for veteran housing vouchers, those who have served will continue to face the risk of homelessness on our streets.',
 'clean energy startups': 'Neglecting clean energy startups will stifle the innovative breakthroughs needed to solve the most difficult challenges of the climate crisis.',
 'electric bus fleets': 'Failing to fund electric bus fleets will ensure that city air remains polluted by the diesel exhaust of traditional public transit.',
 'renewable cooling systems': 'Without support for renewable cooling systems, the rising demand for air conditioning will place an unsustainable burden on the electrical grid.',
 'sustainable fishing gear': 'Ignoring sustainable fishing gear will result in the continued capture of endangered marine species and the depletion of ocean life.',
 'ocean thermal energy': 'Failing to invest in ocean thermal energy prevents the utilization of a constant renewable power source for tropical and coastal regions.',
 'forest fire lookouts': 'Without support for forest fire lookouts, small blazes will go undetected until they become large, uncontrollable, and deadly disasters.',
 'public data centers': 'Neglecting public data centers will force the government to store sensitive citizen information on private or foreign servers with less security.',
 'open science initiatives': 'Failing to fund open science initiatives will slow down the pace of medical and technological discovery by restricting access to research.',
 'community tool libraries': 'Without support for community tool libraries, low-income residents will lack the equipment necessary to maintain their homes and start projects.',
 'neighborhood tool sharing': 'Ignoring neighborhood tool sharing will result in more household waste as families are forced to buy tools they rarely use.',
 'specialized nursing education': 'Failing to invest in specialized nursing education will worsen the healthcare shortage and lead to poorer patient outcomes in hospitals.',
 'rare mineral stockpiles': 'Without support for rare mineral stockpiles, national industries will remain highly vulnerable to sudden international supply chain shocks.',
 'advanced polymer research': 'Neglecting advanced polymer research will allow the continued production of plastics that persist in the environment for hundreds of years.',
 'public compost facilities': 'Failing to fund public compost facilities will result in the waste of organic materials that could have enriched agricultural soil.',
 'sustainable concrete development': 'Without support for sustainable concrete development, the global construction industry will remain a top source of greenhouse gas emissions.',
 'tidal surge barriers': 'Ignoring tidal surge barriers will leave major coastal cities defenseless against the inevitable rise of sea levels and intense storms.',
 'autonomous shuttle loops': 'Failing to invest in autonomous shuttle loops will prevent cities from implementing more efficient and affordable last-mile public transportation solutions.',
 'youth coding camps': 'Without support for youth coding camps, the next generation will lack the digital skills needed for the future labor market.',
 'urban waterway restoration': 'Neglecting urban waterway restoration will leave city canals as polluted and neglected areas instead of thriving public green spaces.',
 'public charging docks': 'Failing to fund public charging docks will leave citizens without a way to stay connected in increasingly digital urban environments.',
 'smart traffic signals': 'Without support for smart traffic signals, cities will continue to suffer from unnecessary idling, higher fuel consumption, and wasted time.',
 'industrial heat pumps': 'Ignoring industrial heat pumps will force factories to continue burning fossil fuels for processes that could be easily electrified.',
 'methane leak detection': 'Failing to invest in methane leak detection will allow a highly potent greenhouse gas to go unmonitored and fuel rapid warming.',
 'aquifer recharge systems': 'Without support for aquifer recharge systems, groundwater supplies will be depleted, leaving communities vulnerable to extreme and long-lasting droughts.',
 'sustainable irrigation tech': 'Neglecting sustainable irrigation tech will result in the depletion of freshwater sources as farms continue to use inefficient watering methods.',
 'citizen science apps': 'Failing to fund citizen science apps will result in a lack of community-led environmental monitoring and reduced public scientific engagement.',
 'public health laboratories': 'Without support for public health laboratories, the nation will lack the diagnostic capacity needed to identify and stop new viral outbreaks.',
 'emergency surgical centers': 'Ignoring emergency surgical centers will lead to higher mortality rates for trauma patients who require immediate and specialized medical care.',
 'rehabilitative sports programs': 'Failing to invest in rehabilitative sports programs will delay the recovery of individuals with physical injuries and limit their social reintegration.',
 'accessible playground equipment': 'Without support for accessible playground equipment, children with disabilities will remain excluded from the social and physical benefits of park play.',
 'sustainable livestock feed': 'Neglecting sustainable livestock feed will ensure that meat production remains a major driver of global deforestation and environmental degradation.',
 'precision forestry tools': 'Failing to fund precision forestry tools will lead to less efficient timber management and reduced carbon sequestration in our national forests.',
 'biodiversity corridors': 'Without support for biodiversity corridors, wildlife populations will become isolated, leading to genetic decline and a higher risk of extinction.',
 'urban wetland preservation': 'Ignoring urban wetland preservation will increase the risk of city flooding and allow pollutants to flow directly into local rivers.',
 'public transit sensors': 'Failing to invest in public transit sensors will leave agencies without the data needed to optimize routes and reduce passenger wait times.',
 'renewable aviation research': 'Without support for renewable aviation research, the aerospace industry will remain one of the most difficult sectors to decarbonize successfully.',
 'clean steel manufacturing': 'Neglecting clean steel manufacturing will ensure that the production of essential building materials continues to release massive amounts of carbon.',
 'green ammonia production': 'Failing to fund green ammonia production prevents the shipping industry from adopting a zero-carbon fuel alternative to traditional diesel engines.',
 'sustainable brick making': 'Without support for sustainable brick making, the building industry will continue to rely on energy-intensive and highly polluting manufacturing processes.',
 'bio-based plastics': 'Ignoring bio-based plastics will ensure our continued dependence on petroleum-based products that create a permanent waste legacy in the oceans.',
 'mycelium building materials': 'Failing to invest in mycelium building materials will delay the development of compostable and energy-efficient alternatives for the construction industry.',
 'recycled aluminum plants': 'Without support for recycled aluminum plants, the country will continue to waste immense amounts of energy on the primary smelting of ore.',
 'public art galleries': 'Neglecting public art galleries will limit cultural access and reduce the vibrancy of city centers that rely on tourism and creativity.',
 'community radio stations': 'Failing to fund community radio stations will leave local voices without a platform and reduce access to hyper-local news and information.',
 'youth orchestra programs': 'Without support for youth orchestra programs, many children will lose the opportunity to develop musical skills and the benefits of teamwork.',
 'senior digital literacy': 'Ignoring senior digital literacy will isolate older populations from essential online services and make them more vulnerable to internet scams.',
 'migrant language classes': 'Failing to invest in migrant language classes will result in slower social integration and limit the economic contributions of new residents.',
 'refugee resettlement centers': 'Without support for refugee resettlement centers, families fleeing from danger will lack the stability needed to rebuild their lives in safety.',
 'public swimming pools': 'Neglecting public swimming pools will reduce opportunities for affordable recreation and lead to a lack of life-saving swimming skills.',
 'municipal fiber optics': 'Failing to fund municipal fiber optics will leave many neighborhoods without the ultra-fast internet needed for remote work and education.',
 'clean construction equipment': 'Without support for clean construction equipment, urban development will continue to be a primary source of loud noise and air pollution.',
 'electric freight rail': 'Ignoring electric freight rail will keep the nation dependent on carbon-heavy trucking for the movement of essential industrial and consumer goods.',
 'autonomous delivery bots': 'Failing to invest in autonomous delivery bots will prevent cities from reducing traffic congestion caused by traditional last-mile delivery vans.',
 'sustainable packaging research': 'Without support for sustainable packaging research, the retail sector will continue to generate millions of tons of single-use plastic waste.',
 'ocean acidification monitoring': 'Neglecting ocean acidification monitoring will leave our fishing industries unprepared for the chemical changes that threaten the survival of shellfish.',
 'coral reef restoration': 'Failing to fund coral reef restoration will lead to the collapse of marine nurseries and the loss of natural storm protection.',
 'mangrove forest protection': 'Without support for mangrove forest protection, coastal areas will face greater storm damage and the loss of massive carbon sequestration capacity.',
 'peatland rewetting projects': 'Ignoring peatland rewetting projects will allow degraded bogs to continue leaking enormous amounts of stored greenhouse gases into the atmosphere.',
 'glacier preservation tech': "Failing to invest in glacier preservation tech will accelerate the loss of the world's primary freshwater reservoirs and drive sea-level rise.",
 'river flow sensors': 'Without support for river flow sensors, farmers will lack the data needed for efficient irrigation and flood risk management will suffer.',
 'public park toilets': 'Neglecting public park toilets will make outdoor recreation less accessible for families, the elderly, and those with certain medical needs.',
 'sidewalk repair programs': 'Failing to fund sidewalk repair programs will make cities less walkable and pose a direct physical danger to pedestrians and the disabled.',
 'accessible transit vans': 'Without support for accessible transit vans, citizens with mobility impairments will remain isolated and unable to reach essential medical services.',
 'electric ferry services': 'Ignoring electric ferry services will ensure that coastal transit remains a source of water pollution and loud, disruptive engine noise.',
 'sustainable port infrastructure': 'Failing to invest in sustainable port infrastructure will allow international shipping hubs to remain major hotspots for local air and water pollution.',
 'green hydrogen storage': 'Without support for green hydrogen storage, the nation will be unable to maintain a stable supply of renewable energy during low production.',
 'solid state batteries': 'Neglecting solid state batteries will stall the progress of electric vehicles, keeping them more expensive and less efficient than traditional cars.',
 'modular reactor design': 'Failing to fund modular reactor design will prevent the nation from adopting a more affordable and flexible form of clean nuclear power.',
 'fusion energy prototypes': 'Without support for fusion energy prototypes, we may never achieve the breakthrough needed for a nearly limitless source of clean power.',
 'space-based solar power': 'Ignoring space-based solar power prevents the collection of constant solar energy that is never blocked by the atmosphere or the night.',
 'lunar base research': 'Failing to invest in lunar base research will allow other nations to dominate the next era of space exploration and resource utilization.',
 'asteroid mining policy': 'Without support for asteroid mining policy, the commercial exploration of space will lack the legal framework needed for peaceful and fair development.',
 'satellite internet arrays': 'Neglecting satellite internet arrays will leave the most remote global populations permanently excluded from the benefits of the digital economy.',
 'hypersonic travel research': 'Failing to fund hypersonic travel research will cause the national aerospace industry to fall behind in the next leap of global transportation.',
 'nanotechnology safety labs': 'Without support for nanotechnology safety labs, we risk the release of new materials into the environment without understanding their health impacts.',
 'synthetic biology ethics': 'Ignoring synthetic biology ethics could lead to the irresponsible design of organisms that pose a threat to public health or biodiversity.',
 'genomic sequencing centers': 'Failing to invest in genomic sequencing centers will prevent doctors from diagnosing genetic conditions early and providing life-saving, personalized medical treatments.',
 'personalized nutrition programs': 'Without support for personalized nutrition programs, the population will continue to suffer from generalized dietary advice that ignores individual metabolic health.',
 'preventative dental care': 'Neglecting preventative dental care will lead to an increase in painful oral diseases and higher costs for restorative dental surgeries later.',
 'mobile health vans': 'Failing to fund mobile health vans will leave isolated rural communities without the basic medical checkups necessary for preventing serious illness.',
 'community birth centers': 'Without support for community birth centers, expectant mothers will have fewer options for safe and personalized maternal healthcare during their pregnancies.',
 'palliative care units': 'Ignoring palliative care units will leave terminally ill patients without the specialized support needed to manage pain and maintain their dignity.',
 'mental health crisis': 'Failing to invest in mental health crisis response teams will result in more dangerous interactions between the police and individuals in distress.',
 'substance abuse counseling': 'Without support for substance abuse counseling, more individuals will remain trapped in the cycle of addiction, harming themselves and their communities.',
 'homeless shelter beds': 'Failing to fund homeless shelter beds will force more people to sleep on the streets, increasing the risk of exposure and illness.',
 'domestic violence refuges': 'Without support for domestic violence refuges, victims will be left without a safe place to escape from dangerous and abusive home situations.',
 'foster care support': 'Ignoring foster care support will result in less stability for children in the system, leading to poorer long-term educational and social outcomes.',
 'adoption assistance programs': 'Failing to invest in adoption assistance programs will leave more children in state care without the chance to find a permanent family.',
 'early literacy kits': 'Without support for early literacy kits, children from low-income families will continue to fall behind in reading before they even start school.',
 'STEM kits for schools': 'Neglecting STEM kits for schools will leave students without the hands-on tools necessary to spark an interest in science and technology careers.',
 'dual-enrollment scholarships': 'Failing to fund dual-enrollment scholarships will prevent many motivated high school students from beginning their college education and reducing their future debt.',
 'teacher salary subsidies': 'Without support for teacher salary subsidies, the best educators will continue to leave the profession for higher-paying roles in the private sector.',
 'school meal programs': 'Ignoring school meal programs will result in children being too hungry to learn, leading to lower test scores and poorer developmental outcomes.',
 'student debt relief': 'Failing to invest in student debt relief will prevent an entire generation from buying homes and fully participating in the national economy.',
 'financial literacy classes': 'Without support for financial literacy classes, citizens will remain more vulnerable to predatory lending and struggle to save for their retirement.',
 'civic education programs': 'Neglecting civic education programs will lead to a less informed electorate and lower levels of public participation in the democratic process.',
 'adult retraining grants': 'Failing to fund adult retraining grants will leave millions of workers stranded in dying industries without a path to new employment opportunities.',
 'apprenticeship tax credits': 'Without support for apprenticeship tax credits, businesses will be less likely to train the next generation of highly skilled technical workers.',
 'small farm equipment': 'Ignoring small farm equipment will leave local farmers unable to compete with large industrial operations, threatening the diversity of the food supply.',
 'local farmers markets': 'Failing to invest in local farmers markets will reduce the availability of fresh produce and harm the livelihoods of independent local growers.',
 'urban beekeeping initiatives': 'Without support for urban beekeeping initiatives, city environments will suffer from a lack of pollination and a decline in plant biodiversity.',
 'native wildflower meadows': 'Neglecting native wildflower meadows will result in the loss of critical habitats for bees and butterflies that are essential for agriculture.',
 'pollinator habitat grants': 'Failing to fund pollinator habitat grants will contribute to the continued decline of insect populations that are vital for global food production.',
 'invasive species removal': 'Without support for invasive species removal, native ecosystems will be overrun, leading to a loss of local biodiversity and environmental health.',
 'soil carbon testing': "Ignoring soil carbon testing will prevent farmers from knowing how to improve their land's ability to store carbon and fight warming.",
 'water desalinization tech': 'Failing to invest in water desalinization tech will leave coastal regions without a reliable alternative when traditional freshwater sources eventually run dry.',
 'greywater recycling systems': 'Without support for greywater recycling systems, households will continue to waste millions of gallons of water that could have been reused safely.',
 'smart water valves': 'Neglecting smart water valves will result in undetected leaks in city pipes that waste precious water and cause expensive structural damage.',
 'public shower facilities': 'Failing to fund public shower facilities will deny homeless individuals a basic necessity, leading to worse hygiene and increased public health risks.',
 'urban cooling centers': 'Without support for urban cooling centers, the elderly and vulnerable will remain at high risk of death during extreme summer heatwaves.',
 'weatherization grant programs': 'Ignoring weatherization grant programs will force low-income families to pay higher utility bills and remain in drafty, energy-inefficient homes.',
 'energy audit services': 'Failing to invest in energy audit services will leave homeowners unaware of the simple changes they could make to lower their energy bills.',
 'low-interest green loans': 'Without support for low-interest green loans, the transition to solar energy will remain too expensive for many average middle-class families.',
 'community land trusts': 'Neglecting community land trusts will lead to the permanent loss of affordable housing as land prices continue to skyrocket in urban areas.',
 'cooperative housing models': 'Failing to fund cooperative housing models will limit the options for citizens to own their homes through community-led and affordable means.',
 'rent control administration': 'Without support for rent control administration, families will be vulnerable to sudden and massive price hikes that lead to displacement and homelessness.',
 'public zoning reform': 'Ignoring public zoning reform will prevent the development of diverse housing types, leading to higher prices and worsening the national housing shortage.',
 'neighborhood safety patrols': 'Failing to invest in neighborhood safety patrols will leave residents feeling less secure and more vulnerable to crime in their local areas.',
 'de-escalation training programs': 'Without support for de-escalation training programs, police interactions are more likely to result in unnecessary violence and the loss of public trust.',
 'body-worn cameras': 'Neglecting body-worn cameras will reduce accountability in law enforcement and make it harder to resolve disputes between the police and citizens.',
 'forensic science labs': 'Failing to fund forensic science labs will lead to backlogs in criminal evidence and delayed justice for the victims of serious crimes.',
 'judicial case management': 'Without support for judicial case management, the court system will remain slow and inefficient, denying many citizens their right to a timely trial.',
 'legal aid services': 'Ignoring legal aid services will leave low-income individuals without the representation needed to defend themselves in court against powerful interests.',
 'public defender funding': 'Failing to invest in public defender funding will undermine the constitutional right to counsel and result in unfair outcomes in the justice system.',
 'restorative justice centers': 'Without support for restorative justice centers, the legal system will focus solely on punishment rather than healing the community and reducing recidivism.',
 'victim compensation funds': 'Neglecting victim compensation funds will leave those hurt by crime without the financial support they need to recover and rebuild their lives.',
 'anti-corruption task forces': "Failing to fund anti-corruption task forces will allow the misuse of public funds to go unpunished and erode the public's trust in government.",
 'election security systems': 'Without support for election security systems, the democratic process remains vulnerable to foreign hacking and the manipulation of national vote counts.',
 'secure voting tech': 'Ignoring secure voting tech will make it harder for citizens to cast their ballots and reduce confidence in the final election results.',
 'government transparency portals': 'Failing to invest in government transparency portals will keep the public in the dark about how their tax dollars are being spent.',
 'open data APIs': 'Without support for open data APIs, the public will be unable to develop helpful digital tools that improve the use of city services.',
 'public records archives': 'Neglecting public records archives will lead to the decay and loss of important historical documents and vital national information for future generations.',
 'cultural heritage digitization': 'Failing to fund cultural heritage digitization will prevent millions from accessing museum collections and historical archives that define our shared national culture.',
 'indigenous language schools': 'Without support for indigenous language schools, many ancient tribal languages will go extinct, taking with them centuries of unique human history.',
 'traditional craft preservation': 'Ignoring traditional craft preservation will lead to the permanent disappearance of unique artistic skills and the loss of local cultural heritage.',
 'public sculpture commissions': 'Failing to invest in public sculpture commissions will result in dull city environments and fewer opportunities for local artists to enrich public life.',
 'community mural projects': 'Without support for community mural projects, urban walls will remain gray and neglected instead of telling the stories of the people who live there.',
 'youth theater grants': 'Neglecting youth theater grants will deny young people a creative outlet and the chance to develop important public speaking and social skills.',
 'local film incentives': 'Failing to fund local film incentives will cause production companies to leave the area, taking jobs and economic growth to other regions.',
 'sustainable tourism boards': 'Without support for sustainable tourism boards, popular landmarks will be overwhelmed by visitors, leading to environmental damage and local social friction.',
 'national trail systems': 'Ignoring national trail systems will leave citizens with fewer places for outdoor recreation and reduce the economic benefits of nature-based tourism.',
 'mountain bike paths': 'Failing to invest in mountain bike paths will result in fewer opportunities for healthy outdoor exercise and the loss of tourism for mountain towns.',
 'accessible hiking trails': 'Neglecting accessible hiking trails will continue to exclude people with mobility issues from the physical and mental benefits of visiting national parks.',
 'urban beach maintenance': 'Failing to fund urban beach maintenance will lead to polluted shorelines and the loss of popular summer recreation areas for city dwellers.',
 'public pier repair': 'Without support for public pier repair, these beloved coastal structures will become unsafe and have to be closed to the public permanently.',
 'riverfront boardwalks': 'Ignoring riverfront boardwalks will prevent cities from revitalizing their waterways and creating safe, walkable paths that support local businesses.',
 'floating solar farms': 'Failing to invest in floating solar farms will result in more land being diverted from agriculture for the production of renewable electricity.',
 'wave energy converters': 'Without support for wave energy converters, the nation will fail to capture the constant and clean power potential found in the ocean.',
 'micro-hydro turbines': 'Neglecting micro-hydro turbines will leave remote riverside communities without a reliable and low-impact source of clean, renewable energy for their homes.',
 'kinetic floor tiling': 'Failing to fund kinetic floor tiling will miss the chance to generate clean power from the movement of thousands of people in transit.',
 'waste heat recovery': 'Without support for waste heat recovery systems, industrial plants will continue to lose massive amounts of energy that could have been repurposed.',
 'carbon-neutral glass production': 'Ignoring carbon-neutral glass production will ensure that the manufacturing of building materials remains a major source of greenhouse gas emissions.',
 'sustainable rubber research': 'Failing to invest in sustainable rubber research will keep the tire industry dependent on petroleum-based chemicals that are harmful to the environment.',
 'bio-solvent development': 'Without support for bio-solvent development, industries will continue to use toxic chemicals that pollute the air and water around our factories.',
 'green chemistry labs': 'Neglecting green chemistry labs will prevent the discovery of manufacturing processes that create less waste and use fewer hazardous substances in industry.',
 'circular textile hubs': 'Failing to fund circular textile hubs will result in millions of tons of old clothing ending up in landfills instead of being recycled.',
 'reclaimed wood markets': 'Without support for reclaimed wood markets, valuable timber from old buildings will be wasted while more trees are cut down for construction.',
 'industrial symbiosis parks': 'Ignoring industrial symbiosis parks prevents factories from sharing resources, which leads to higher costs and more industrial waste for the planet.',
 'smart waste bins': 'Failing to invest in smart waste bins will result in inefficient garbage collection and more trash overflowing on city streets during busy times.',
 'compostable cutlery research': 'Without support for compostable cutlery research, single-use plastics will continue to pollute our oceans and harm marine life for centuries to come.',
 'biodegradable sensor networks': 'Neglecting biodegradable sensor networks will leave farmers with more electronic waste in their fields after they finish monitoring their crops for health.',
 'public environmental monitoring': 'Failing to fund public environmental monitoring will leave citizens without the transparent data needed to hold polluters accountable in their own communities.',
 'citizen air sensors': 'Without support for citizen air sensors, the government will lack the detailed neighborhood-level data required to tackle local air pollution hotspots effectively.',
 'noise pollution barriers': 'Ignoring noise pollution barriers will result in high stress levels and poor sleep for residents living near increasingly busy and loud highways.',
 'light pollution reduction': 'Failing to invest in light pollution reduction will disrupt nocturnal wildlife and prevent the public from enjoying the natural view of the stars.',
 'dark sky preserves': 'Without support for dark sky preserves, the night sky will continue to vanish under urban glow, harming both science and the environment.'}

# %%
loss_2 = {'renewable energy': "Ignoring renewable energy will likely prolong the nation's dependence on carbon-intensive fuels and accelerate the negative impacts of global climate change.",
 'public transportation': 'Overlooking public transportation will inevitably lead to denser traffic gridlock and higher levels of respiratory illness from excessive vehicle exhaust.',
 'mental health services': 'By not funding mental health services, the government risks a rise in social instability and a significant decline in overall workplace productivity.',
 'urban green spaces': 'Disregarding urban green spaces will leave metropolitan areas more vulnerable to extreme heat and deny residents necessary psychological relief from city life.',
 'wildlife conservation': 'Failing to prioritize wildlife conservation will result in the permanent extinction of native species and the collapse of vital local ecological systems.',
 'high-speed rail': 'Neglecting high-speed rail means interstate travel will remain slow and inefficient, hindering the movement of people and the growth of commerce.',
 'universal childcare': 'Without support for universal childcare, many families will face severe financial burdens that restrict parental participation in the modern labor market.',
 'affordable housing': 'Ignoring affordable housing will exacerbate the regional homelessness crisis and drive essential workers further away from the communities they serve daily.',
 'rural broadband access': 'Failing to expand rural broadband access will leave farming communities digitally isolated and unable to compete in the increasingly online global economy.',
 'clean water infrastructure': 'Disregarding clean water infrastructure will expose the public to dangerous contaminants and lead to the gradual decay of essential municipal utility networks.',
 'teacher training programs': 'Without support for teacher training programs, the quality of classroom instruction will stagnate, leaving students unprepared for a complex future economy.',
 'vocational education': "Neglecting vocational education will create a massive shortage of skilled technicians required to maintain the nation's critical electrical and plumbing systems.",
 'carbon capture technology': 'Ignoring carbon capture technology will make it virtually impossible for heavy manufacturing industries to achieve their mandatory carbon reduction goals on time.',
 'cybersecurity defense': 'Failing to invest in cybersecurity defense will leave national power grids and private banking systems open to devastating foreign digital interference.',
 'early childhood development': 'By overlooking early childhood development, society will likely face higher costs for remedial education and corrective social services in the future.',
 'sustainable agriculture': 'Neglecting sustainable agriculture will lead to the rapid degradation of topsoil and threaten the long-term reliability of the domestic food supply.',
 'public health research': 'Without support for public health research, the nation remains highly vulnerable to the sudden outbreak of new and increasingly resistant viral pathogens.',
 'disaster resilient infrastructure': 'Ignoring disaster resilient infrastructure will result in higher casualty rates and astronomical repair costs following the next major environmental catastrophe.',
 'smart city technology': 'Failing to fund smart city technology will leave municipalities with inefficient energy management and outdated systems for monitoring public safety and traffic.',
 'space exploration': 'Disregarding space exploration will cause the country to lose its competitive edge in aerospace engineering and miss out on potential scientific breakthroughs.',
 'quantum computing research': 'By neglecting quantum computing research, the government risks falling behind in the global race for advanced encryption and high-speed data processing.',
 'elderly care facilities': 'Failing to invest in elderly care facilities will lead to a decline in quality of life for seniors and place strain on families.',
 'ocean plastic removal': 'Without support for ocean plastic removal, marine life will continue to ingest toxic waste, eventually contaminating the entire human food chain.',
 'forest restoration': "Ignoring forest restoration will decrease the earth's natural ability to sequester carbon and lead to more frequent and severe localized flooding.",
 'youth mentorship programs': 'Failing to fund youth mentorship programs could result in higher juvenile delinquency rates and a loss of potential for many at-risk students.',
 'domestic manufacturing': 'Neglecting domestic manufacturing will leave the national economy fragile and overly dependent on the stability of complex international trade routes.',
 'green hydrogen production': 'Without support for green hydrogen production, heavy transport sectors will struggle to find a viable alternative to polluting diesel fuels for long-distance shipping.',
 'literacy initiatives': 'By overlooking literacy initiatives, the government allows a significant portion of the population to remain underemployed and excluded from the digital economy.',
 'veteran support services': 'Failing to fund veteran support services will result in higher rates of untreated trauma and social alienation among those who served the nation.',
 'electric vehicle charging': 'Neglecting electric vehicle charging will delay the transition to clean transit and keep urban areas trapped in a cycle of air pollution.',
 'biodiversity protection': 'Without support for biodiversity protection, the loss of various plant and animal species will weaken the natural resilience of the global environment.',
 'grid modernization': 'Ignoring grid modernization will lead to frequent localized blackouts and prevent the seamless integration of new wind and solar power sources.',
 'small business grants': 'Failing to provide small business grants will stifle local innovation and allow large monopolies to dominate the regional economic landscape.',
 'maternal health care': 'By neglecting maternal health care, the nation will likely see a rise in pregnancy complications and a decline in infant health outcomes.',
 'workforce retraining': 'Without support for workforce retraining, millions of employees in declining industries will face permanent unemployment as automation reshapes the modern labor market.',
 'emergency response systems': 'Ignoring emergency response systems will result in slower medical intervention times and a higher number of preventable deaths during domestic crises.',
 'public library systems': 'Failing to invest in public library systems will deprive low-income residents of free educational resources and a safe space for community learning.',
 'pedestrian safety infrastructure': 'Neglecting pedestrian safety infrastructure will ensure that city streets remains dangerous for walkers and lead to a higher rate of traffic accidents.',
 'organic farming subsidies': 'Without support for organic farming subsidies, chemical-intensive agriculture will continue to dominate the market and harm local soil health and water supplies.',
 'semiconductor production': 'Ignoring semiconductor production will leave the national technology sector vulnerable to foreign supply shocks and hinder the development of domestic electronics.',
 'artificial intelligence ethics': 'Failing to fund artificial intelligence ethics will allow biased algorithms to proliferate, potentially leading to widespread social discrimination and loss of privacy.',
 'bilingual education': 'By overlooking bilingual education, the nation will lack the linguistic diversity required to engage effectively in the competitive international business arena.',
 'waste-to-energy plants': 'Neglecting waste-to-energy plants will result in the continued growth of landfills and the loss of a valuable source of renewable electricity.',
 'social housing projects': 'Without support for social housing projects, the cycle of poverty will deepen for many families who lack a stable and permanent residence.',
 'preventative medicine': 'Ignoring preventative medicine will lead to an explosion in long-term healthcare costs as chronic diseases go undetected until they require expensive surgery.',
 'flood defense systems': 'Failing to invest in flood defense systems will leave thousands of coastal homes and businesses unprotected from increasingly frequent and severe storms.',
 'community college funding': 'By neglecting community college funding, the state prevents many talented students from obtaining the higher education necessary for modern career success.',
 'renewable heating systems': 'Without support for renewable heating systems, residential buildings will continue to emit large quantities of greenhouse gases throughout the long winter months.',
 'precision medicine': "Ignoring precision medicine will delay the arrival of more effective treatments that are specifically tailored to an individual patient's unique genetic profile.",
 'coastal erosion prevention': 'Failing to prioritize coastal erosion prevention will lead to the permanent loss of shoreline habitats and the destruction of valuable seaside infrastructure.',
 'adult education centers': 'Neglecting adult education centers will result in a stagnant labor force that cannot keep up with the rapid pace of technological change.',
 'rare disease research': 'Without support for rare disease research, thousands of patients will be left without the specialized medical breakthroughs required for their specific conditions.',
 'national park maintenance': "Ignoring national park maintenance will result in the degradation of the country's most iconic natural landmarks and a decline in eco-tourism revenue.",
 'solar panel manufacturing': 'Failing to fund solar panel manufacturing will leave the domestic energy market dependent on imported technology and stifle local high-tech job growth.',
 'clean air initiatives': 'Without support for clean air initiatives, the public will suffer from higher rates of chronic asthma and other serious respiratory health issues.',
 'prison rehabilitation programs': 'Neglecting prison rehabilitation programs will likely lead to higher recidivism rates and the continued social and financial costs of repeat offenses.',
 'drought resistant crops': 'By overlooking drought resistant crops, the agricultural sector remains highly vulnerable to changing climate patterns and potential large-scale food shortages.',
 'high-tech startups': 'Failing to invest in high-tech startups will slow the pace of national innovation and allow other countries to lead in emerging industries.',
 'marine protected areas': 'Ignoring marine protected areas will allow overfishing to continue unchecked, leading to the total collapse of vital commercial and recreational fish stocks.',
 'after-school programs': 'Without support for after-school programs, many children will lack a structured environment for learning and social growth during critical afternoon hours.',
 'geothermal energy': 'Neglecting geothermal energy will prevent the nation from accessing a constant source of clean, renewable baseload power that operates regardless of weather.',
 'biofuel development': 'Failing to prioritize biofuel development will keep the aviation industry dependent on fossil fuels and hinder efforts to reach net-zero carbon goals.',
 'language preservation': 'By overlooking language preservation, society risks losing the rich cultural heritage and unique perspectives of various indigenous and minority communities.',
 'public arts programs': 'Ignoring public arts programs will result in less vibrant communities and the loss of creative outlets that inspire and unify the citizenry.',
 'infectious disease surveillance': 'Without support for infectious disease surveillance, the nation will be unable to detect and contain new viral threats before they become pandemics.',
 'cycling infrastructure': 'Failing to invest in cycling infrastructure will discourage healthy transit habits and contribute to continued urban traffic congestion and higher carbon emissions.',
 'desalination plants': 'Neglecting desalination plants will leave arid regions without a backup water supply, potentially leading to severe water rationing and economic instability.',
 'solid waste management': 'Without support for solid waste management, cities will face mounting trash problems that contaminate groundwater and harm the health of local residents.',
 'regenerative medicine': 'Ignoring regenerative medicine will delay the development of therapies that could heal damaged organs and permanently cure previously untreatable medical conditions.',
 'local food systems': 'Failing to fund local food systems will keep communities dependent on long-distance supply chains that are vulnerable to fuel price fluctuations.',
 'bridge repair projects': 'Neglecting bridge repair projects will compromise the safety of the national transport network and lead to costly emergency closures and economic disruptions.',
 'special education resources': 'Without support for special education resources, students with unique learning needs will be left behind, limiting their future independence and economic potential.',
 'battery storage technology': 'Ignoring battery storage technology will prevent the efficient use of solar and wind power, stalling the national transition toward a clean grid.',
 'indigenous land management': 'Failing to prioritize indigenous land management will result in the loss of ancient ecological knowledge that is vital for preserving regional biodiversity.',
 'remote learning tools': 'Without support for remote learning tools, the educational gap between wealthy urban areas and impoverished rural regions will continue to grow.',
 'satellite communication': 'By overlooking satellite communication, the nation risks losing its ability to provide reliable internet and emergency services to remote and underserved populations.',
 'water recycling systems': 'Neglecting water recycling systems will lead to the unnecessary depletion of natural aquifers and exacerbate water scarcity during periods of extreme drought.',
 'labor market transparency': 'Failing to invest in labor market transparency will result in persistent wage inequality and the inefficient allocation of talent across various industrial sectors.',
 'microgrid development': 'Without support for microgrid development, critical facilities like hospitals will remain vulnerable to total power loss during major failures of the central grid.',
 'sustainable forestry': "Ignoring sustainable forestry will lead to widespread habitat loss and the long-term degradation of the nation's valuable timber and water resources.",
 'physical education': 'By neglecting physical education, the government contributes to a more sedentary population and higher long-term healthcare costs related to obesity.',
 'immunization programs': 'Failing to fund immunization programs will lead to the resurgence of preventable diseases, putting the most vulnerable members of society at risk.',
 'circular economy initiatives': 'Without support for circular economy initiatives, the nation will continue to waste valuable raw materials and generate an unsustainable amount of trash.',
 'homelessness prevention': 'Ignoring homelessness prevention will force more individuals into expensive emergency systems and perpetuate a cycle of social and economic instability.',
 'tidal power': 'Failing to invest in tidal power will prevent coastal regions from utilizing the predictable and massive energy potential of the rising and falling sea.',
 'urban farming': 'Without support for urban farming, city residents will remain disconnected from their food sources and miss out on local nutritional and environmental benefits.',
 'citizen science projects': 'Neglecting citizen science projects will result in less data for environmental monitoring and a decline in public engagement with the scientific community.',
 'dam safety': 'By overlooking dam safety, the government risks catastrophic structural failures that could destroy entire downstream communities and vital hydroelectric power assets.',
 'public square renovation': 'Failing to fund public square renovation will lead to the decay of community centers and a loss of local foot traffic for small businesses.',
 'space debris removal': 'Without support for space debris removal, the orbital environment will become increasingly dangerous for the satellites that manage global communications and navigation.',
 'advanced robotics': 'Ignoring advanced robotics will cause domestic manufacturers to lose their competitive edge against more automated and cost-efficient international competitors.',
 'community health clinics': 'Failing to invest in community health clinics will leave low-income residents without affordable medical care, leading to more frequent emergency room visits.',
 'historic preservation': "Without support for historic preservation, the nation's architectural heritage will crumble, erasing the physical history that connects us to our cultural past.",
 'food security programs': 'Neglecting food security programs will result in millions of citizens suffering from hunger and the long-term health consequences of persistent malnutrition.',
 'public broadcasting': 'By overlooking public broadcasting, the state risks a more fragmented media landscape where educational content and unbiased news are less accessible.',
 'peatland restoration': 'Failing to fund peatland restoration will allow massive amounts of stored carbon to escape into the atmosphere, further driving global temperature increases.',
 'stem cell research': 'Without support for stem cell research, the medical community will miss the chance to develop revolutionary cures for currently irreversible spinal injuries.',
 'district heating': 'Ignoring district heating will result in continued energy inefficiency in urban areas as individual buildings rely on separate, carbon-heavy boiler systems.',
 'migrant integration services': 'Failing to invest in migrant integration services will lead to social isolation and prevent new residents from contributing their skills to the economy.',
 'energy efficient appliances': 'Without support for energy efficient appliances, the national power grid will remain under heavy strain and household utility bills will stay high.',
 'rural healthcare clinics': 'Neglecting rural healthcare clinics will leave remote populations with dangerously long travel times for life-saving medical treatment during sudden health crises.',
 'national security technology': 'By overlooking national security technology, the country remains vulnerable to increasingly sophisticated threats from modern warfare and high-tech global espionage.',
 'neighborhood revitalization': 'Failing to fund neighborhood revitalization will lead to the further decay of urban centers and a decline in local property values and safety.',
 'online safety education': 'Without support for online safety education, children and elderly citizens will be more susceptible to digital fraud, bullying, and predatory online behavior.',
 'sustainable fashion research': 'Ignoring sustainable fashion research will allow the apparel industry to remain a major contributor to global water pollution and industrial waste.',
 'park and ride': 'Failing to invest in park and ride facilities will discourage commuters from using transit, leading to continued traffic congestion in busy city centers.',
 'industrial decarbonization': 'Without support for industrial decarbonization, heavy manufacturing will remain a primary source of carbon emissions, hindering national climate change mitigation efforts.',
 'pediatric care': 'Neglecting pediatric care will result in poorer health outcomes for the youngest citizens and higher costs for treating preventable developmental issues later.',
 'river cleanup operations': 'By overlooking river cleanup operations, the government allows toxic pollutants to persist in waterways, harming both wildlife and potential human drinking supplies.',
 'weather forecasting systems': 'Failing to fund weather forecasting systems will result in less accurate storm warnings, increasing the risk of property damage and loss of life.',
 'green building materials': 'Without support for green building materials, the construction industry will continue to rely on energy-intensive products that contribute heavily to global warming.',
 'soil health restoration': "Ignoring soil health restoration will lead to a decrease in agricultural yields and the loss of the land's natural ability to hold water.",
 'public transit subsidies': 'Failing to invest in public transit subsidies will make commuting unaffordable for many low-income workers, resulting in more cars on the road.',
 'aerospace engineering': 'Without support for aerospace engineering, the nation will fall behind in developing the quieter and more efficient aircraft needed for future travel.',
 'mental health apps': 'By neglecting mental health apps, the state misses an opportunity to provide low-cost, immediate support to individuals struggling with anxiety or depression.',
 'clean energy jobs': 'Failing to fund clean energy jobs will result in a workforce that is ill-equipped for the inevitable transition away from traditional fossil fuels.',
 'oceanographic research': 'Without support for oceanographic research, we will remain ignorant of the critical changes in sea temperature and acidity that affect global weather.',
 'community gardens': 'Ignoring community gardens will deprive urban residents of a valuable source of fresh produce and a place for social interaction and stress relief.',
 'disability access improvements': 'Failing to invest in disability access improvements will continue to marginalize millions of citizens by preventing their full participation in public life.',
 'hydrogen fuel cells': 'Without support for hydrogen fuel cells, the nation will struggle to decarbonize the heavy trucking and shipping industries that cannot use batteries.',
 'carbon sequestration': 'By overlooking carbon sequestration, the government misses a vital tool for removing existing greenhouse gases from the atmosphere to meet climate goals.',
 'anti-smoking campaigns': 'Neglecting anti-smoking campaigns will lead to higher rates of preventable lung disease and place an unnecessary burden on the national healthcare budget.',
 'autonomous vehicle safety': 'Failing to fund autonomous vehicle safety will result in public distrust of new technology and a higher risk of accidents during its rollout.',
 'microchip design': 'Without support for microchip design, domestic industries will remain dependent on foreign hardware, posing a significant risk to national economic and digital security.',
 'youth sports facilities': 'Ignoring youth sports facilities will contribute to higher rates of childhood obesity and a lack of constructive recreational outlets for the younger generation.',
 'sustainable tourism': 'Failing to invest in sustainable tourism will result in the over-exploitation of natural landmarks and the degradation of local cultural heritage sites.',
 'wastewater treatment': 'Without support for wastewater treatment, communities face a higher risk of environmental pollution and the spread of dangerous, preventable waterborne diseases.',
 'nutrition assistance': 'Neglecting nutrition assistance will leave many children without the healthy food required for proper physical growth and effective classroom learning performance.',
 'reforestation projects': 'By overlooking reforestation projects, the nation will lose critical habitats for wildlife and the natural air-filtering benefits provided by healthy forest ecosystems.',
 'advanced materials science': 'Failing to fund advanced materials science will slow the development of lighter, stronger components needed for the next generation of renewable energy technologies.',
 'family planning services': 'Without support for family planning services, the state may see a rise in unintended pregnancies and a greater strain on public social welfare.',
 'cyber-physical systems': 'Ignoring cyber-physical systems will leave national infrastructure, such as power plants and water systems, more vulnerable to both mechanical and digital failures.',
 'public records digitization': 'Failing to invest in public records digitization will maintain government inefficiency and make it harder for citizens to access important historical and legal documents.',
 'clean cooking fuels': 'Without support for clean cooking fuels, millions will continue to suffer from the toxic health effects of indoor smoke from traditional wood stoves.',
 'wildfire prevention': 'Neglecting wildfire prevention will result in more frequent and intense forest fires that destroy property and release massive amounts of carbon into the air.',
 'vaccine manufacturing': 'By overlooking vaccine manufacturing, the nation risks being unable to quickly produce and distribute life-saving medicine during the next global health crisis.',
 'marine biology research': 'Failing to fund marine biology research will leave us unable to protect fragile coral reefs and the various species that rely on them.',
 'smart irrigation': 'Without support for smart irrigation, agriculture will continue to waste immense amounts of water, leading to the depletion of local reservoirs and rivers.',
 'alternative protein research': 'Ignoring alternative protein research will ensure that the environmental impact of traditional livestock farming continues to grow at an unsustainable and dangerous rate.',
 'urban drainage systems': 'Failing to invest in urban drainage systems will lead to frequent street flooding and the costly decay of city roads and building foundations.',
 'digital literacy training': 'Without support for digital literacy training, many citizens will be unable to navigate essential online services, from banking to digital government applications.',
 'biotechnology innovation': 'Neglecting biotechnology innovation will delay the development of new treatments for chronic illnesses and more resilient food crops for a changing climate.',
 'poverty alleviation': 'By overlooking poverty alleviation, the government risks increased social inequality and the long-term stagnation of the national economic growth potential.',
 'public safety equipment': 'Failing to fund public safety equipment will leave first responders without the modern tools needed to effectively save lives during fires and accidents.',
 'heritage site protection': "Without support for heritage site protection, the country's most significant historical landmarks will continue to decay and be lost to future generations.",
 'sustainable aviation fuel': 'Ignoring sustainable aviation fuel will ensure that air travel remains a major contributor to global greenhouse gas emissions for the foreseeable future.',
 'green shipping lanes': 'Failing to invest in green shipping lanes will allow the maritime industry to continue polluting the oceans and damaging coastal air quality unchecked.',
 'low-carbon cement': 'Without support for low-carbon cement, the construction industry will remain a top source of CO2, making it difficult to achieve national climate targets.',
 'integrated pest management': 'Neglecting integrated pest management will lead to an overreliance on toxic chemicals that harm the environment and enter the human food supply chain.',
 'nuclear power plants': 'By overlooking nuclear power plants, the nation will struggle to maintain a stable, carbon-free source of baseload electricity to support renewable energy grids.',
 'universal basic income': 'Failing to invest in universal basic income could result in widespread economic hardship as automation and artificial intelligence reduce the number of traditional jobs.',
 'high-density housing': 'Without support for high-density housing, urban sprawl will continue to destroy natural habitats and increase the time and cost of daily commuting.',
 'semiconductor research labs': 'Ignoring semiconductor research labs will lead to a loss of technological sovereignty and leave the nation dependent on foreign innovation for critical electronics.',
 'pediatric mental health': 'Failing to fund pediatric mental health will leave many children struggling with untreated trauma, leading to more significant behavioral and social issues in adulthood.',
 'coastal levee systems': 'Without support for coastal levee systems, many seaside communities will remain defenseless against the rising threat of catastrophic storm surges and floods.',
 'carbon tax infrastructure': 'By neglecting carbon tax infrastructure, the government fails to create a market incentive for businesses to reduce their harmful greenhouse gas emissions effectively.',
 'public Wi-Fi networks': 'Failing to invest in public Wi-Fi networks will widen the digital divide and prevent low-income students from accessing the information needed for school.',
 'rare earth mining': "Without support for rare earth mining, the nation's high-tech and defense sectors will remain dangerously dependent on foreign suppliers for critical raw materials.",
 'sustainable textile production': 'Ignoring sustainable textile production will allow the clothing industry to continue being a major source of global water waste and chemical pollution.',
 'recycled plastic roads': 'Failing to fund recycled plastic roads will result in the continued accumulation of plastic waste in landfills instead of using it for infrastructure.',
 'hydrogen fueling stations': 'Without support for hydrogen fueling stations, zero-emission fuel cell vehicles will never become a practical option for long-haul freight and commercial transportation.',
 'organic waste collection': 'Neglecting organic waste collection will lead to more methane being released from landfills and the loss of valuable nutrients for agricultural soil.',
 'marine turbine arrays': 'By overlooking marine turbine arrays, the country misses a chance to generate clean, predictable electricity from the constant and powerful movement of tides.',
 'smart electrical meters': 'Failing to invest in smart electrical meters will prevent homeowners from accurately tracking their energy use and finding ways to lower their bills.',
 'public drone delivery': 'Without support for public drone delivery, the distribution of life-saving medical supplies to remote or congested areas will remain slow and inefficient.',
 'quantum encryption tools': 'Ignoring quantum encryption tools will leave national security data vulnerable to future cyberattacks that could easily break traditional and currently secure coding methods.',
 'vertical farming facilities': 'Failing to fund vertical farming facilities will keep the food supply vulnerable to weather-related disruptions and increase the environmental cost of food transport.',
 'urban canopy expansion': 'Without support for urban canopy expansion, city streets will remain hotter and less pleasant, increasing the energy demand for air conditioning in summer.',
 'disaster warning apps': 'By neglecting disaster warning apps, the government risks a slower public response to emergency situations, potentially leading to a higher number of casualties.',
 'high-tech vocational labs': 'Without support for high-tech vocational labs, the workforce will lack the hands-on experience needed for high-paying roles in the modern manufacturing sector.',
 'bilingual signage systems': 'Ignoring bilingual signage systems will make public services more difficult to navigate for international tourists and non-native residents within the local community.',
 'public water filtration': 'Failing to fund public water filtration will allow microplastics and other emerging contaminants to persist in the drinking supply, potentially harming long-term health.',
 'migrant job training': 'Without support for migrant job training, new arrivals will struggle to integrate economically, leading to higher social welfare costs and lower tax revenue.',
 'veteran housing vouchers': 'By neglecting veteran housing vouchers, the nation fails in its moral duty to ensure that those who served have a safe place to live.',
 'clean energy startups': 'Failing to invest in clean energy startups will slow the development of the innovative breakthroughs required to solve the most difficult environmental challenges.',
 'electric bus fleets': 'Without support for electric bus fleets, city transit will continue to contribute to local air pollution and high noise levels in busy neighborhoods.',
 'renewable cooling systems': 'Ignoring renewable cooling systems will result in higher greenhouse gas emissions as the demand for traditional air conditioning grows due to warming temperatures.',
 'sustainable fishing gear': 'Failing to fund sustainable fishing gear will lead to more accidental deaths of endangered marine species and the further depletion of global fish stocks.',
 'ocean thermal energy': 'Without support for ocean thermal energy, coastal and island nations will miss out on a constant, carbon-free source of renewable electricity from the sea.',
 'forest fire lookouts': 'By overlooking forest fire lookouts, the state risks failing to detect small blazes before they grow into uncontrollable and destructive natural disasters.',
 'public data centers': 'Failing to invest in public data centers will leave the government dependent on private corporations for the storage and security of sensitive national data.',
 'open science initiatives': 'Without support for open science initiatives, the pace of global research will be slowed by paywalls and the restriction of vital scientific information.',
 'community tool libraries': 'Ignoring community tool libraries will result in more household waste and prevent low-income residents from accessing the tools needed for basic home repairs.',
 'neighborhood tool sharing': 'Failing to fund neighborhood tool sharing will miss a chance to build community bonds and reduce the unnecessary consumption of rarely used home equipment.',
 'specialized nursing education': 'Without support for specialized nursing education, the healthcare system will be ill-equipped to handle the complex needs of an increasingly aging national population.',
 'rare mineral stockpiles': 'By neglecting rare mineral stockpiles, the nation remains vulnerable to sudden international supply shocks that could halt the production of essential high-tech goods.',
 'advanced polymer research': 'Failing to invest in advanced polymer research will allow the continued use of plastics that do not break down, harming global soil and water.',
 'public compost facilities': 'Without support for public compost facilities, organic waste will continue to rot in landfills, releasing methane and wasting valuable nutrients for local agriculture.',
 'sustainable concrete development': 'Ignoring sustainable concrete development will ensure that the building of new infrastructure remains a significant and avoidable source of global carbon emissions.',
 'tidal surge barriers': 'Failing to fund tidal surge barriers will leave major coastal cities defenseless against the inevitable rise in sea levels and destructive storm events.',
 'autonomous shuttle loops': 'Without support for autonomous shuttle loops, airports and urban centers will continue to rely on less efficient and more labor-intensive transit solutions.',
 'youth coding camps': 'By neglecting youth coding camps, the government misses an opportunity to equip the next generation with the digital skills necessary for future success.',
 'urban waterway restoration': 'Failing to invest in urban waterway restoration will leave city canals as polluted eyesores instead of thriving habitats for fish and local bird species.',
 'public charging docks': 'Without support for public charging docks, citizens in increasingly digital urban environments will struggle to keep their essential communication devices powered while traveling.',
 'smart traffic signals': 'Ignoring smart traffic signals will result in more idling vehicles, higher fuel consumption, and continued frustration for commuters stuck in avoidable city traffic.',
 'industrial heat pumps': 'Failing to fund industrial heat pumps will force factories to continue burning fossil fuels for processes that could easily be electrified and cleaned.',
 'methane leak detection': 'By overlooking methane leak detection, the state allows a highly potent greenhouse gas to escape into the atmosphere, significantly accelerating global climate warming.',
 'aquifer recharge systems': 'Failing to invest in aquifer recharge systems will lead to the permanent depletion of groundwater reserves, leaving the region vulnerable to future water crises.',
 'sustainable irrigation tech': 'Without support for sustainable irrigation tech, farms will continue to use excessive amounts of water, leading to the depletion of local rivers and lakes.',
 'citizen science apps': 'Ignoring citizen science apps will result in less data for environmental monitoring and a decline in public participation in the scientific research process.',
 'public health laboratories': "Failing to fund public health laboratories will leave the nation's doctors without the diagnostic tools needed to identify and stop new infectious diseases.",
 'emergency surgical centers': 'Without support for emergency surgical centers, trauma victims in remote areas will face a much higher risk of death due to delayed medical intervention.',
 'rehabilitative sports programs': 'By neglecting rehabilitative sports programs, the government hinders the physical and social recovery of individuals who have suffered serious or life-altering physical injuries.',
 'accessible playground equipment': 'Failing to invest in accessible playground equipment will continue to exclude children with disabilities from the physical and social benefits of outdoor public play.',
 'sustainable livestock feed': 'Without support for sustainable livestock feed, the meat industry will continue to contribute to global deforestation and high levels of methane emissions.',
 'precision forestry tools': 'Ignoring precision forestry tools will lead to less efficient woodland management and a decrease in the health and carbon-storing potential of forests.',
 'biodiversity corridors': 'Failing to fund biodiversity corridors will isolate wildlife populations, making them more vulnerable to disease and reducing their long-term chances of survival and growth.',
 'urban wetland preservation': 'Without support for urban wetland preservation, cities will lose a natural defense against flooding and a vital habitat for many different bird species.',
 'public transit sensors': 'By overlooking public transit sensors, transit agencies will lack the real-time data needed to improve bus frequency and reduce waiting times for passengers.',
 'renewable aviation research': 'Failing to invest in renewable aviation research will leave the airline industry without the technology needed to reduce its significant impact on the environment.',
 'clean steel manufacturing': "Without support for clean steel manufacturing, one of the world's most essential materials will continue to be produced using outdated and highly polluting methods.",
 'green ammonia production': 'Ignoring green ammonia production will prevent the development of a carbon-free fuel source for the shipping industry and the production of sustainable agricultural fertilizers.',
 'sustainable brick making': 'Failing to fund sustainable brick making will ensure that the construction industry remains dependent on energy-intensive kilns that release large amounts of carbon.',
 'bio-based plastics': 'Without support for bio-based plastics, the world will continue to be buried under petroleum-derived waste that takes hundreds of years to break down naturally.',
 'mycelium building materials': 'By neglecting mycelium building materials, the government misses an opportunity to promote a compostable and low-energy alternative to traditional and carbon-heavy building insulation.',
 'recycled aluminum plants': 'Failing to invest in recycled aluminum plants will result in the unnecessary mining of new ore, which uses far more energy and harms the environment.',
 'public art galleries': 'Without support for public art galleries, the community will lose out on free cultural enrichment and a space for local artists to exhibit.',
 'community radio stations': 'Ignoring community radio stations will leave local musicians and neighborhood news without a platform, leading to a loss of unique regional cultural identity.',
 'youth orchestra programs': 'Failing to fund youth orchestra programs will deny many talented young people the chance to develop their musical skills and experience the joy of performing.',
 'senior digital literacy': 'Without support for senior digital literacy, older citizens will be increasingly isolated from the modern world and more vulnerable to various online financial scams.',
 'migrant language classes': 'By overlooking migrant language classes, the nation will struggle to integrate new residents, leading to social friction and reduced economic participation in the workforce.',
 'refugee resettlement centers': 'Failing to invest in refugee resettlement centers will leave families who have fled conflict without the basic stability and support needed to rebuild lives.',
 'public swimming pools': 'Without support for public swimming pools, many families will lack an affordable way to stay active and learn the essential life-saving skill of swimming.',
 'municipal fiber optics': 'Ignoring municipal fiber optics will leave some neighborhoods with slow and unreliable internet, putting local students and businesses at a significant disadvantage today.',
 'clean construction equipment': 'Failing to fund clean construction equipment will ensure that new building projects continue to cause significant air and noise pollution in densely populated neighborhoods.',
 'electric freight rail': 'Without support for electric freight rail, the long-distance transport of goods will remain a major source of diesel exhaust and greenhouse gas emissions.',
 'autonomous delivery bots': 'By neglecting autonomous delivery bots, cities miss an opportunity to reduce traffic congestion and lower the carbon footprint associated with last-mile parcel deliveries.',
 'sustainable packaging research': 'Failing to invest in sustainable packaging research will allow the continued use of single-use plastics that end up polluting our rivers and global ocean systems.',
 'ocean acidification monitoring': 'Without support for ocean acidification monitoring, the seafood industry will be unprepared for the chemical changes that could destroy valuable shellfish populations and ecosystems.',
 'coral reef restoration': 'Ignoring coral reef restoration will lead to the collapse of underwater ecosystems and the loss of natural storm protection for many vulnerable coastal communities.',
 'mangrove forest protection': "Failing to fund mangrove forest protection will result in the loss of one of the planet's most effective natural systems for sequestering atmospheric carbon.",
 'peatland rewetting projects': 'Without support for peatland rewetting projects, dry bogs will continue to release massive amounts of carbon, making it much harder to reach climate goals.',
 'glacier preservation tech': 'By overlooking glacier preservation tech, the world risks the faster loss of vital freshwater sources and an accelerated rise in global sea levels.',
 'river flow sensors': 'Failing to invest in river flow sensors will leave water managers without the precise data needed to prevent floods and manage agricultural irrigation effectively.',
 'public park toilets': 'Without support for public park toilets, many green spaces will become less accessible to families with small children and the elderly for long visits.',
 'sidewalk repair programs': 'Ignoring sidewalk repair programs will make neighborhoods less walkable and pose a serious trip hazard for the elderly and those with mobility impairments.',
 'accessible transit vans': 'Failing to fund accessible transit vans will leave citizens with disabilities without a reliable way to get to work or attend important medical appointments.',
 'electric ferry services': 'Without support for electric ferry services, water-based transit will remain a source of diesel pollution and loud engine noise that disrupts coastal wildlife and residents.',
 'sustainable port infrastructure': 'By neglecting sustainable port infrastructure, the shipping industry will continue to be a major source of air pollution in the coastal cities it serves.',
 'green hydrogen storage': 'Failing to invest in green hydrogen storage will prevent the nation from saving clean energy for use during periods of low wind or solar production.',
 'solid state batteries': 'Without support for solid state batteries, the progress of electric vehicles and portable electronics will be slowed by the limitations of current battery technology.',
 'modular reactor design': 'Ignoring modular reactor design will prevent the adoption of a safer and more affordable nuclear power option that can provide carbon-free baseload energy.',
 'fusion energy prototypes': 'Failing to fund fusion energy prototypes will delay the potential discovery of a nearly limitless and completely clean source of power for the entire world.',
 'space-based solar power': 'Without support for space-based solar power, we miss the chance to collect constant energy from the sun that is never blocked by weather.',
 'lunar base research': 'By overlooking lunar base research, the nation risks falling behind in the next era of space discovery and the potential utilization of extraterrestrial resources.',
 'asteroid mining policy': 'Failing to invest in asteroid mining policy will create legal uncertainty that could hinder the responsible and peaceful future development of resources in space.',
 'satellite internet arrays': 'Without support for satellite internet arrays, remote global populations will remain disconnected from the modern digital economy and essential online educational resources.',
 'hypersonic travel research': 'Ignoring hypersonic travel research will cause the national aerospace sector to fall behind international competitors in the race for the next generation of flight.',
 'nanotechnology safety labs': 'Failing to fund nanotechnology safety labs could result in the release of new materials into the environment without a proper understanding of their health risks.',
 'synthetic biology ethics': 'Without support for synthetic biology ethics, the development of new organisms could proceed without the necessary safeguards to protect public health and the environment.',
 'genomic sequencing centers': 'By neglecting genomic sequencing centers, the state misses the chance to provide personalized medical care that could save thousands of lives through early diagnosis.',
 'personalized nutrition programs': 'Failing to invest in personalized nutrition programs will result in continued high rates of diet-related chronic diseases that could have been prevented with tailored advice.',
 'preventative dental care': 'Without support for preventative dental care, many children will suffer from painful and avoidable tooth decay that requires expensive and invasive treatments later.',
 'mobile health vans': 'Ignoring mobile health vans will leave residents in remote or underserved areas without access to basic medical checkups and essential life-saving vaccinations.',
 'community birth centers': 'Failing to fund community birth centers will leave expectant mothers with fewer choices for safe and personalized care during the birth of their children.',
 'palliative care units': 'Without support for palliative care units, many patients at the end of their lives will be left without the specialized support needed for dignity.',
 'mental health crisis': 'By neglecting mental health crisis response teams, the government risks continuing to use police for medical issues, which can lead to unnecessary and tragic outcomes.',
 'substance abuse counseling': 'Failing to invest in substance abuse counseling will leave many individuals trapped in the cycle of addiction, harming themselves and their families and communities.',
 'homeless shelter beds': 'Ignoring homeless shelter beds will force more people to sleep in unsafe public areas, increasing the risk of exposure and the spread of illness.',
 'domestic violence refuges': 'Failing to fund domestic violence refuges will leave many individuals without a safe place to go when they are in danger from an abusive partner.',
 'foster care support': 'Without support for foster care support, children in the system will lack the resources they need for a stable upbringing and future academic success.',
 'adoption assistance programs': 'By overlooking adoption assistance programs, the state may see more children remaining in long-term foster care instead of finding a permanent and loving home.',
 'early literacy kits': 'Failing to invest in early literacy kits will leave children from disadvantaged backgrounds behind in reading skills before they even enter the classroom.',
 'STEM kits for schools': 'Without support for STEM kits for schools, students will lack the hands-on tools needed to develop the skills for the high-tech jobs of the future.',
 'dual-enrollment scholarships': 'Ignoring dual-enrollment scholarships will prevent many motivated students from starting their college degrees early and reducing the overall cost of their future education.',
 'teacher salary subsidies': 'Failing to fund teacher salary subsidies will lead to a shortage of qualified educators as they leave for better-paying jobs in the private sector.',
 'school meal programs': 'Without support for school meal programs, many children will be too hungry to concentrate in class, leading to lower academic performance and poor health.',
 'student debt relief': 'By neglecting student debt relief, the government risks discouraging young people from pursuing higher education and delays their ability to contribute fully to the economy.',
 'financial literacy classes': 'Failing to invest in financial literacy classes will leave citizens more vulnerable to predatory lending practices and less prepared for their own long-term financial stability.',
 'civic education programs': 'Without support for civic education programs, the next generation will be less informed about their rights and the importance of participating in the democratic process.',
 'adult retraining grants': 'Ignoring adult retraining grants will leave workers in declining industries without the financial help they need to learn new and relevant skills for today.',
 'apprenticeship tax credits': 'Failing to fund apprenticeship tax credits will result in fewer businesses offering the on-the-job training needed to build a highly skilled and productive national workforce.',
 'small farm equipment': 'Without support for small farm equipment, local family farms will struggle to remain viable against large-scale industrial operations, reducing the diversity of food.',
 'local farmers markets': 'By overlooking local farmers markets, the state misses a chance to support small-scale agriculture and provide residents with fresh, healthy, and locally-grown produce.',
 'urban beekeeping initiatives': 'Failing to invest in urban beekeeping initiatives will result in lower pollination rates for city gardens and a decline in the local honeybee population.',
 'native wildflower meadows': 'Without support for native wildflower meadows, essential pollinators like butterflies will lose the habitats they need to survive and help our food crops grow.',
 'pollinator habitat grants': 'Ignoring pollinator habitat grants will contribute to the continued global decline of bees, which are vital for the success of the agricultural industry.',
 'invasive species removal': 'Failing to fund invasive species removal will allow non-native plants and animals to overrun local ecosystems, destroying biodiversity and harming the health of our forests.',
 'soil carbon testing': 'Without support for soil carbon testing, farmers will lack the precise information needed to manage their land in a way that helps fight climate change.',
 'water desalinization tech': 'By neglecting water desalinization tech, the nation risks running out of freshwater in arid regions as traditional water sources are depleted by rising demand.',
 'greywater recycling systems': 'Failing to invest in greywater recycling systems will lead to the unnecessary waste of millions of gallons of water that could have been used for irrigation.',
 'smart water valves': 'Without support for smart water valves, undetected leaks in the municipal water system will continue to waste precious resources and lead to expensive repairs.',
 'public shower facilities': 'Ignoring public shower facilities will deprive homeless citizens of a basic necessity, leading to poorer personal hygiene and increased risks to overall public health.',
 'urban cooling centers': 'Failing to fund urban cooling centers will leave elderly and vulnerable residents at high risk during extreme heatwaves that are becoming more common and severe.',
 'weatherization grant programs': 'Without support for weatherization grant programs, low-income families will continue to pay high energy bills for homes that are difficult and expensive to keep warm.',
 'energy audit services': 'By overlooking energy audit services, homeowners will miss out on the information needed to make simple and effective changes to lower their energy consumption.',
 'low-interest green loans': 'Failing to invest in low-interest green loans will make it much more difficult for the average family to afford the cost of switching to solar.',
 'community land trusts': 'Without support for community land trusts, the price of urban land will remain high, making it nearly impossible for many to ever own homes.',
 'cooperative housing models': 'Ignoring cooperative housing models will limit the options for affordable, community-focused living arrangements that help residents build long-term stability and save money together.',
 'rent control administration': 'Failing to fund rent control administration will leave many tenants vulnerable to unfair and sudden price increases that could lead to displacement and even homelessness.',
 'public zoning reform': 'Without support for public zoning reform, cities will struggle to build the diverse range of housing needed to meet the demands of a growing population.',
 'neighborhood safety patrols': 'By neglecting neighborhood safety patrols, the government misses an opportunity to provide a visible and friendly presence that helps residents feel more secure at home.',
 'de-escalation training programs': 'Failing to invest in de-escalation training programs for police will result in more violent outcomes during interactions with the public and a loss of trust.',
 'body-worn cameras': 'Without support for body-worn cameras, it will be much harder to ensure accountability and provide clear evidence during disputes between law enforcement and the public.',
 'forensic science labs': 'Ignoring forensic science labs will lead to backlogs in testing and delays in the justice system, making it harder to solve crimes and protect residents.',
 'judicial case management': 'Failing to fund judicial case management will result in a slow and inefficient court system where citizens have to wait years for a final legal decision.',
 'legal aid services': 'Without support for legal aid services, many low-income individuals will be left without any representation in court, leading to unfair and often biased legal outcomes.',
 'public defender funding': 'By neglecting public defender funding, the state fails to uphold the right to a fair trial for every citizen, regardless of their financial background.',
 'restorative justice centers': 'Failing to invest in restorative justice centers will keep the focus solely on punishment instead of healing the community and helping offenders turn their lives around.',
 'victim compensation funds': 'Without support for victim compensation funds, those who have been hurt by a crime will be left without the financial help needed to recover and rebuild.',
 'anti-corruption task forces': "Ignoring anti-corruption task forces will allow the misuse of public funds and power to continue, eroding the public's trust in their own government and leaders.",
 'election security systems': 'Failing to fund election security systems will leave the democratic process vulnerable to hacking and foreign interference, threatening the integrity of every single vote cast.',
 'secure voting tech': 'Without support for secure voting tech, the process of casting a ballot will remain less efficient and more vulnerable to errors and potential security risks.',
 'government transparency portals': 'By overlooking government transparency portals, the state makes it harder for citizens to see how their tax money is spent and hold leaders accountable.',
 'open data APIs': 'Failing to invest in open data APIs will prevent developers from creating useful apps that help the public use transportation, parks, and other city services.',
 'public records archives': 'Without support for public records archives, the physical and digital history of the nation will be at risk of being lost or destroyed over time.',
 'cultural heritage digitization': 'Ignoring cultural heritage digitization will mean that many of our national treasures remain hidden from the public and are not preserved for future digital access.',
 'indigenous language schools': 'Failing to fund indigenous language schools will lead to the permanent loss of unique and ancient languages that are a vital part of our culture.',
 'traditional craft preservation': 'Without support for traditional craft preservation, the unique skills of local artists will vanish, leaving the community with fewer handmade and culturally significant products.',
 'public sculpture commissions': 'By neglecting public sculpture commissions, the government misses an opportunity to make the city more beautiful and provide a platform for our local creative artists.',
 'community mural projects': 'Failing to invest in community mural projects will leave urban spaces looking gray and neglected instead of vibrant and full of local neighborhood pride and story.',
 'youth theater grants': 'Without support for youth theater grants, many children will lose out on a fun and educational way to build their self-confidence and public speaking skills.',
 'local film incentives': 'Ignoring local film incentives will cause movie production companies to go elsewhere, taking jobs and economic opportunities away from our local community and businesses.',
 'sustainable tourism boards': 'Failing to fund sustainable tourism boards will lead to the over-exploitation of natural landmarks, causing permanent damage to the very places people want to visit.',
 'national trail systems': 'Without support for national trail systems, citizens will have fewer places to enjoy the great outdoors and experience the health benefits of walking and hiking.',
 'mountain bike paths': 'By neglecting mountain bike paths, the state misses an opportunity to encourage an active lifestyle and attract new visitors to our mountain towns and parks.',
 'accessible hiking trails': 'Without support for accessible hiking trails, people with mobility challenges will continue to be excluded from enjoying the beauty and fresh air of our national forests.',
 'urban beach maintenance': 'Ignoring urban beach maintenance will lead to dirty and unsafe sand and water, making it impossible for families to enjoy these popular city recreation areas.',
 'public pier repair': 'Failing to fund public pier repair will lead to the decay of these beloved coastal landmarks, making them unsafe for the public to visit and enjoy.',
 'riverfront boardwalks': 'Without support for riverfront boardwalks, city waterways will remain less accessible, and local businesses along the water will miss out on potential customers and growth.',
 'floating solar farms': 'By overlooking floating solar farms, the nation misses a chance to produce clean energy without using up land that could be used for agriculture or parks.',
 'wave energy converters': "Failing to invest in wave energy converters will leave coastal regions without a way to harness the constant and powerful energy of the ocean's waves today.",
 'micro-hydro turbines': 'Without support for micro-hydro turbines, small mountain villages will remain dependent on long-distance power lines that are often unreliable and expensive to maintain in storms.',
 'kinetic floor tiling': 'Ignoring kinetic floor tiling in busy areas will mean missing an opportunity to generate clean, supplemental power from the natural movement of large crowds every day.',
 'waste heat recovery': 'Failing to fund waste heat recovery will result in industries continuing to waste massive amounts of energy that could have been used to save money.',
 'carbon-neutral glass production': 'Without support for carbon-neutral glass production, the manufacturing of windows for new homes and offices will remain a significant and avoidable source of pollution.',
 'sustainable rubber research': 'By neglecting sustainable rubber research, the tire industry will remain dependent on chemicals made from oil, which are harmful to the global and local environment.',
 'bio-solvent development': 'Failing to invest in bio-solvent development will mean that factories continue to use toxic cleaning chemicals that can harm the health of workers and neighbors.',
 'green chemistry labs': 'Without support for green chemistry labs, the discovery of safer and more environmentally friendly ways to make medicine and household products will be significantly slowed down.',
 'circular textile hubs': 'Ignoring circular textile hubs will lead to more old clothing ending up in landfills instead of being recycled into new and useful textile products today.',
 'reclaimed wood markets': 'Failing to fund reclaimed wood markets will result in old timber being wasted while new forests are cut down to meet the demand for building.',
 'industrial symbiosis parks': 'Without support for industrial symbiosis parks, factories will continue to operate separately, wasting resources that could have been shared to save money and the environment.',
 'smart waste bins': 'By overlooking smart waste bins, cities will continue to use inefficient garbage collection routes that waste fuel and lead to overflowing trash in busy areas.',
 'compostable cutlery research': 'Failing to invest in compostable cutlery research will ensure that single-use plastic forks and spoons continue to pollute our oceans and harm marine life daily.',
 'biodegradable sensor networks': "Without support for biodegradable sensor networks, farmers will be left with plastic and electronic waste in their fields after they finish monitoring their soil's health.",
 'public environmental monitoring': 'Ignoring public environmental monitoring will leave the citizenry without the transparent data needed to know if the air and water in their neighborhood are safe.',
 'citizen air sensors': 'Failing to fund citizen air sensors will prevent residents from tracking pollution in their local streets and advocating for a cleaner and healthier environment for children.',
 'noise pollution barriers': 'Without support for noise pollution barriers, families living near busy highways will continue to suffer from high levels of stress and poor sleep every single night.',
 'light pollution reduction': 'By neglecting light pollution reduction, the city will continue to waste energy and disrupt the natural cycles of birds and other nocturnal wildlife in our area.',
 'dark sky preserves': 'Failing to invest in dark sky preserves will mean that the natural beauty of the stars will be lost to our children as urban glow spreads.'}

# %%
# Check for identical keys
assert set(gain_1.keys()) == set(gain_2.keys())
assert set(gain_2.keys()) == set(loss_1.keys())
assert set(loss_1.keys()) == set(loss_2.keys())

# Combine into dfs
gain_1_df = pd.DataFrame.from_dict(gain_1, orient='index', columns=['gain_response'])
loss_1_df = pd.DataFrame.from_dict(loss_1, orient='index', columns=['loss_response'])
df1 = gain_1_df.join(loss_1_df)

gain_2_df = pd.DataFrame.from_dict(gain_2, orient='index', columns=['gain_response'])
loss_2_df = pd.DataFrame.from_dict(loss_2, orient='index', columns=['loss_response'])
df2 = gain_2_df.join(loss_2_df)

# Compile final df
df = pd.concat([df1, df2])
df.index.name = 'policy'
df.sort_index(inplace=True)

# Export
df.to_csv('policies_responses.csv')
